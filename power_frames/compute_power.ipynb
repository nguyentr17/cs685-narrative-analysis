# %% [markdown]
# NOTE: This notebook copied and adapted from [https://github.com/maria-antoniak/power-frames/blob/main/example_notebook.ipynb]

# %%
from collections import defaultdict
import os
import pickle
import random

import numpy as np
import pandas as pd

import sys
sys.path.append('power-frames/')
#sys.path.append('power-frames-ORIGINAL/')
import power_frames as pf

# %%
import json

# %% [markdown]
# ### Load dataset

# %%
#dataset_dir_path = 'narratives.csv' 
dataset_dir_path = '../narrative_detection/narrative_posts_by_trained_classification.csv'

# %%
df = pd.read_csv(dataset_dir_path)
stories = df['selftext'].tolist()
len(stories)
# Out:
# 7676

# %%
story_ids = [str(i) for i in range(len(stories))]
len(story_ids)
# Out:
# 7676

# %% [markdown]
# ### Define Personas

# %%
persona_pattern_dict = {'narrator': r'I|me',
                        'reader': r'you',
                        'SO_male': r'BF|bf|boyfriend|husband',
                        'SO_female': r'GF|gf|girlfriend|wife',
                        'SO_neutral': r'partner|spouse',
                        'SO_any': r'partner|spouse|bf|boyfriend|husband|GF|gf|girlfriend|wife',
                        'ex_SO': r'ex|ex bf|ex gf|ex boyfriend|ex girlfriend|ex husband|ex wife|ex spouse',
                        'friend': r'friend|friends|bff|best friend|bestfriend',
                        'family': r'family|mom|mum|dad|mother|father|sibling|brother|sister|son|daughter|grandmother|grandfather|grandma|grandpa|grandson|gran',
                        'ED': r'ED|eating disorder|anorexia|bulimia|binge-eating|binge eating|binge|disorder',
                        'nurse': r'nurse|nurses|np',
                        'doctor': r'doctor|doctors|dr',
                        'therapist': r'therapist|therapists',
                        'medical_prof': r'nurse|nurses|np|doctor|doctors|dr|therapist|therapists|psychologist|psychiatrist',
                        'food': r'food|drink|snack|meal|breakfast|lunch|dinner|dessert|coffee|tea|alcohol|wine|beer|cocktail|soda|juice|water|seltzer'}

# %% [markdown]
# ### Measure power across dataset

# %%
lexicon_path = 'FramesAgencyPower/agency_power.csv'
verb_power_dict = pf.get_verb_power_dict(lexicon_path)
len(verb_power_dict)
# Out:
# 2142

# %%
verb_agency_dict = pf.get_verb_agency_dict(lexicon_path)
len(verb_agency_dict)
# Out:
# 2142

# %%
id_persona_power_dict, \
    id_persona_agency_dict, \
    id_persona_total_dict, \
    id_nsubj_verb_count_dict, \
    id_dobj_verb_count_dict = pf.measure_power(verb_power_dict,
                                               verb_agency_dict,
                                               persona_pattern_dict, 
                                               stories, 
                                               story_ids)
# Out:
# 2023-05-08 17:39:41 Processed 0 out of 7676
# 2023-05-08 17:40:16 Processed 100 out of 7676
# 2023-05-08 17:40:56 Processed 200 out of 7676
# 2023-05-08 17:41:39 Processed 300 out of 7676
# 2023-05-08 17:42:36 Processed 400 out of 7676
# 2023-05-08 17:43:30 Processed 500 out of 7676
# 2023-05-08 17:44:34 Processed 600 out of 7676
# 2023-05-08 17:45:11 Processed 700 out of 7676
# 2023-05-08 17:45:46 Processed 800 out of 7676
# 2023-05-08 17:46:21 Processed 900 out of 7676
# 2023-05-08 17:46:58 Processed 1000 out of 7676
# 2023-05-08 17:47:34 Processed 1100 out of 7676
# 2023-05-08 17:48:10 Processed 1200 out of 7676
# 2023-05-08 17:49:01 Processed 1300 out of 7676
# 2023-05-08 17:49:56 Processed 1400 out of 7676
# 2023-05-08 17:50:32 Processed 1500 out of 7676
# 2023-05-08 17:51:17 Processed 1600 out of 7676
# 2023-05-08 17:51:59 Processed 1700 out of 7676
# 2023-05-08 17:52:38 Processed 1800 out of 7676
# 2023-05-08 17:53:19 Processed 1900 out of 7676
# 2023-05-08 17:54:04 Processed 2000 out of 7676
# 2023-05-08 17:54:40 Processed 2100 out of 7676
# 2023-05-08 17:55:15 Processed 2200 out of 7676
# 2023-05-08 17:55:44 Processed 2300 out of 7676
# 2023-05-08 17:56:19 Processed 2400 out of 7676
# 2023-05-08 17:56:49 Processed 2500 out of 7676
# 2023-05-08 17:57:29 Processed 2600 out of 7676
# 2023-05-08 17:58:02 Processed 2700 out of 7676
# 2023-05-08 17:58:33 Processed 2800 out of 7676
# 2023-05-08 17:59:09 Processed 2900 out of 7676
# 2023-05-08 17:59:46 Processed 3000 out of 7676
# 2023-05-08 18:00:19 Processed 3100 out of 7676
# 2023-05-08 18:00:54 Processed 3200 out of 7676
# 2023-05-08 18:01:33 Processed 3300 out of 7676
# 2023-05-08 18:02:07 Processed 3400 out of 7676
# 2023-05-08 18:02:53 Processed 3500 out of 7676
# 2023-05-08 18:03:33 Processed 3600 out of 7676
# 2023-05-08 18:04:08 Processed 3700 out of 7676
# 2023-05-08 18:04:51 Processed 3800 out of 7676
# 2023-05-08 18:05:36 Processed 3900 out of 7676
# 2023-05-08 18:06:22 Processed 4000 out of 7676
# 2023-05-08 18:07:02 Processed 4100 out of 7676
# 2023-05-08 18:07:39 Processed 4200 out of 7676
# 2023-05-08 18:08:16 Processed 4300 out of 7676
# 2023-05-08 18:08:57 Processed 4400 out of 7676
# 2023-05-08 18:09:42 Processed 4500 out of 7676
# 2023-05-08 18:10:20 Processed 4600 out of 7676
# 2023-05-08 18:11:03 Processed 4700 out of 7676
# 2023-05-08 18:11:38 Processed 4800 out of 7676
# 2023-05-08 18:12:10 Processed 4900 out of 7676
# 2023-05-08 18:12:45 Processed 5000 out of 7676
# 2023-05-08 18:13:16 Processed 5100 out of 7676
# 2023-05-08 18:13:50 Processed 5200 out of 7676
# 2023-05-08 18:14:28 Processed 5300 out of 7676
# 2023-05-08 18:14:58 Processed 5400 out of 7676
# 2023-05-08 18:15:30 Processed 5500 out of 7676
# 2023-05-08 18:16:01 Processed 5600 out of 7676
# 2023-05-08 18:16:28 Processed 5700 out of 7676
# 2023-05-08 18:16:58 Processed 5800 out of 7676
# 2023-05-08 18:17:27 Processed 5900 out of 7676
# 2023-05-08 18:18:00 Processed 6000 out of 7676
# 2023-05-08 18:18:40 Processed 6100 out of 7676
# 2023-05-08 18:19:13 Processed 6200 out of 7676
# 2023-05-08 18:19:43 Processed 6300 out of 7676
# 2023-05-08 18:20:22 Processed 6400 out of 7676
# 2023-05-08 18:21:00 Processed 6500 out of 7676
# 2023-05-08 18:21:26 Processed 6600 out of 7676
# 2023-05-08 18:21:54 Processed 6700 out of 7676
# 2023-05-08 18:22:21 Processed 6800 out of 7676
# 2023-05-08 18:22:49 Processed 6900 out of 7676
# 2023-05-08 18:23:23 Processed 7000 out of 7676
# 2023-05-08 18:23:50 Processed 7100 out of 7676
# 2023-05-08 18:24:24 Processed 7200 out of 7676
# 2023-05-08 18:24:54 Processed 7300 out of 7676
# 2023-05-08 18:25:24 Processed 7400 out of 7676
# 2023-05-08 18:26:01 Processed 7500 out of 7676
# 2023-05-08 18:26:42 Processed 7600 out of 7676

# %%
# save all outputs
folder = 'output/coref_only_outputs/'
if not os.path.exists(folder):
    os.makedirs(folder)

with open(folder + 'id_persona_power_dict.json', 'w') as f:
    json.dump(id_persona_power_dict, f, indent=4)
with open(folder + 'id_persona_agency_dict.json', 'w') as f:
    json.dump(id_persona_agency_dict, f, indent=4)
with open(folder + 'id_persona_total_dict.json', 'w') as f:
    json.dump(id_persona_total_dict, f, indent=4)
with open(folder + 'id_nsubj_verb_count_dict.pkl', 'wb') as f:
    pickle.dump(id_nsubj_verb_count_dict, f)
with open(folder + 'id_dobj_verb_count_dict.pkl', 'wb') as f:
    pickle.dump(id_dobj_verb_count_dict, f)

# %%
stories[-2]
# Out:
# "Sometimes I come to reddit to read about people's purging and restricting experiences bc I'm so tempted to fall back on old habits. I started going to a nutritionist last November and when I started going I was eating max 2 meals a day and purging routinely. But throughout this process it been so frustrating to find articles and stuff about people who restrict eating and purge. I feel like I am all alone. I hear about people who restrict and people who binge eat because that's what gets all the attention when talk about eating disorders. Given I can't even say disorder out loud, but it'd make me feel less alone if I could put myself into some category that wasn't as vague as 'disordered eating' or 'purging disorder' because I feel like the description of purging disorder j talks about purging and not restricting. Also when you read stuff about eating disorders online and talk to people about it nobody ever talks about how FLUID it is. Like I used to purge a lot a lot and then I tried to help myself by stopping and I just started restricting what I eat even more. IT FEELS LIKE A GAME OF WHACK A MOLE!! Also recently I realized that my favorite part of drinking is coming home and throwing up because the best part about it is that I'm not 'purging' NO I'M PULLING TRIG its fun like what ever. But im beginning to realize that its really reflecting purging behavior because I won't have even drunk that much and I won't feel sick but I'll make myself do it anyways bc its kinda socially more acceptable than purging and I can convince myself that its not. And the worse part about it is that I've been telling my nutritionist that I haven't been purging bc I didn't count it right and I was really starting to feel like I was making a comeback but no I've been making myself throw up at least twice a month most months. I go to look online about correlations between drinking and purging disorder and I can't find any and it makes me feel so alone. Who am I supposed to talk to? I don't feel like I can talk to them bc I don't want to trigger them bc u never know what someones dealing with and the only people I know who like talk about their eating disorders are bulimic or anorexic and I know that this is all so personal and I don't want to trigger anyone. But rn it j feels like there's no light at the end of the tunnel. I'm eating 3 meals a day but each ones a struggle. I can't even tell my parents how much I'm struggling bc im so embarrassed. They're the ones sending me to the nutritionist but they think I'm going to talk her about sports nutrition."

# %% [markdown]
# ### Examine scores

# %%
id_persona_score_dict = defaultdict(lambda: defaultdict(float))
for _id, _persona_power_dict in id_persona_power_dict.items():
    for _persona, _polarity_score_dict in _persona_power_dict.items():
        _score = _polarity_score_dict['positive'] - _polarity_score_dict['negative']
        _score /= id_persona_total_dict[_id][_persona]
        id_persona_score_dict[_id][_persona] = _score

# %%
id_persona_agency_score_dict = defaultdict(lambda: defaultdict(float))
for _id, _persona_agency_dict in id_persona_agency_dict.items():
    for _persona, _polarity_score_dict in _persona_agency_dict.items():
        _score = _polarity_score_dict['positive'] - _polarity_score_dict['negative']
        _score /= id_persona_total_dict[_id][_persona]
        id_persona_agency_score_dict[_id][_persona] = _score

# %%
# save all outputs
with open(folder + 'id_persona_score_dict.json', 'w') as f:
    json.dump(id_persona_score_dict, f, indent=4)
with open(folder + 'id_persona_agency_score_dict.json', 'w') as f:
    json.dump(id_persona_agency_score_dict, f, indent=4)

# %%
id_persona_agency_dict['9']
# Out:
# defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#             {'SO_male': defaultdict(int,
#                          {'equal': 2, 'positive': 5, 'negative': 5}),
#              'SO_any': defaultdict(int,
#                          {'equal': 2, 'positive': 5, 'negative': 5}),
#              'friend': defaultdict(int,
#                          {'equal': 2, 'positive': 5, 'negative': 5}),
#              'narrator': defaultdict(int, {'negative': 1, 'positive': 0})})

# %%
id_persona_power_dict['9']
# Out:
# defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#             {'SO_male': defaultdict(int, {'negative': 5, 'positive': 4}),
#              'SO_any': defaultdict(int, {'negative': 5, 'positive': 4}),
#              'friend': defaultdict(int, {'negative': 5, 'positive': 4}),
#              'narrator': defaultdict(int, {'negative': 3, 'positive': 1})})

# %%
id_persona_total_dict['9']
# Out:
# defaultdict(int, {'SO_male': 15, 'SO_any': 15, 'friend': 15, 'narrator': 7})

# %%
id_persona_power_dict
# Out:
# {'0': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'therapist': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'medical_prof': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '1': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 3, 'negative': 0})}),
#  '2': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '3': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {}),
#  '4': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'reader': defaultdict(int, {'negative': 2, 'positive': 1})}),
#  '5': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'ex_SO': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '6': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {}),
#  '7': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 2, 'negative': 2}),
#               'narrator': defaultdict(int, {'positive': 3, 'negative': 0})}),
#  '8': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'SO_female': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'SO_any': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'friend': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'reader': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '9': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'SO_male': defaultdict(int, {'negative': 5, 'positive': 4}),
#               'SO_any': defaultdict(int, {'negative': 5, 'positive': 4}),
#               'friend': defaultdict(int, {'negative': 5, 'positive': 4}),
#               'narrator': defaultdict(int, {'negative': 3, 'positive': 1})}),
#  '10': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'SO_female': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'SO_any': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'friend': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'reader': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '11': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {}),
#  '12': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 3, 'positive': 0})}),
#  '13': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 3, 'negative': 5}),
#               'reader': defaultdict(int, {'negative': 1, 'positive': 1}),
#               'narrator': defaultdict(int, {'negative': 2, 'positive': 1})}),
#  '14': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {}),
#  '15': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '16': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'negative': 3, 'positive': 0})}),
#  '17': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 1}),
#               'food': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '18': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'SO_male': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'SO_any': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'narrator': defaultdict(int, {'positive': 4, 'negative': 2}),
#               'reader': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '19': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '20': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'friend': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'negative': 3, 'positive': 0})}),
#  '21': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 5, 'negative': 1}),
#               'reader': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'ex_SO': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 2}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '22': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'positive': 1, 'negative': 2}),
#               'narrator': defaultdict(int, {'negative': 3, 'positive': 0}),
#               'ED': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '23': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'negative': 1, 'positive': 1}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'ED': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '24': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'ex_SO': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'ED': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '25': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'doctor': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'medical_prof': defaultdict(int,
#                           {'negative': 1, 'positive': 0})}),
#  '26': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '27': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 4, 'negative': 3}),
#               'reader': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'narrator': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '28': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'negative': 2, 'positive': 1}),
#               'ED': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '29': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'reader': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'SO_male': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'SO_any': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'friend': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 1})}),
#  '30': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'positive': 2, 'negative': 1}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '31': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'negative': 2, 'positive': 2}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '32': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'ED': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'SO_male': defaultdict(int, {'positive': 4, 'negative': 2}),
#               'SO_any': defaultdict(int, {'positive': 4, 'negative': 2}),
#               'friend': defaultdict(int, {'positive': 4, 'negative': 2}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '33': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'negative': 4, 'positive': 0})}),
#  '34': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'narrator': defaultdict(int, {'negative': 4, 'positive': 0})}),
#  '35': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int, {'negative': 3, 'positive': 9}),
#               'narrator': defaultdict(int, {'positive': 2, 'negative': 1}),
#               'food': defaultdict(int, {'positive': 1, 'negative': 1})}),
#  '36': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'ED': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'reader': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'friend': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '37': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {}),
#  '38': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'ED': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '39': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'ED': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '40': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 2, 'negative': 2})}),
#  '41': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {}),
#  '42': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '43': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '44': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 2, 'negative': 6}),
#               'therapist': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'medical_prof': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'doctor': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '45': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'ex_SO': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '46': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'ex_SO': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '47': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '48': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int, {'positive': 4, 'negative': 1}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '49': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {}),
#  '50': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'doctor': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'medical_prof': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'negative': 2, 'positive': 1}),
#               'ED': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '51': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 3, 'positive': 0})}),
#  '52': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '53': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '54': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'ED': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '55': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '56': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {}),
#  '57': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'doctor': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'medical_prof': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '58': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 2, 'negative': 0})}),
#  '59': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'ex_SO': defaultdict(int, {'positive': 4, 'negative': 3}),
#               'friend': defaultdict(int, {'positive': 4, 'negative': 3}),
#               'ED': defaultdict(int, {'positive': 4, 'negative': 3}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '60': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '61': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '62': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'negative': 1, 'positive': 1}),
#               'narrator': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '63': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {}),
#  '64': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 3, 'positive': 0})}),
#  '65': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'medical_prof': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 2, 'negative': 0})}),
#  '66': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 3, 'positive': 0})}),
#  '67': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'positive': 1, 'negative': 3}),
#               'narrator': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '68': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 2, 'negative': 2})}),
#  '69': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '70': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'ED': defaultdict(int, {'positive': 1, 'negative': 3}),
#               'narrator': defaultdict(int, {'positive': 2, 'negative': 2}),
#               'food': defaultdict(int, {'positive': 1, 'negative': 3})}),
#  '71': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '72': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {}),
#  '73': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 2}),
#               'ED': defaultdict(int, {'negative': 3, 'positive': 0})}),
#  '74': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 2}),
#               'food': defaultdict(int, {'negative': 5, 'positive': 0})}),
#  '75': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'SO_female': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'SO_any': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'narrator': defaultdict(int, {'positive': 3, 'negative': 5}),
#               'ex_SO': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'friend': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '76': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'ED': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '77': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'narrator': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '78': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '79': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'SO_female': defaultdict(int, {'positive': 7, 'negative': 1}),
#               'SO_any': defaultdict(int, {'positive': 8, 'negative': 1}),
#               'friend': defaultdict(int, {'positive': 7, 'negative': 1}),
#               'narrator': defaultdict(int, {'negative': 4, 'positive': 1}),
#               'reader': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'SO_neutral': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'doctor': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'medical_prof': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'ex_SO': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'nurse': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '80': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'ex_SO': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '81': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'doctor': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'medical_prof': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'family': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'food': defaultdict(int, {'positive': 1, 'negative': 4}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 3})}),
#  '82': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '83': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 4, 'negative': 0}),
#               'narrator': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '84': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 4}),
#               'food': defaultdict(int, {'positive': 1, 'negative': 3})}),
#  '85': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '86': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'SO_neutral': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'SO_any': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'friend': defaultdict(int, {'positive': 4, 'negative': 4})}),
#  '87': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'family': defaultdict(int, {'negative': 3, 'positive': 1})}),
#  '88': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'SO_female': defaultdict(int, {'positive': 2, 'negative': 4}),
#               'SO_any': defaultdict(int, {'positive': 2, 'negative': 4}),
#               'friend': defaultdict(int, {'positive': 2, 'negative': 4}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '89': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 4, 'positive': 1}),
#               'ex_SO': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '90': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 2, 'negative': 1}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'ED': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '91': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 1})}),
#  '92': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int, {'positive': 7, 'negative': 5}),
#               'ED': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'narrator': defaultdict(int, {'negative': 4, 'positive': 0})}),
#  '93': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int, {'positive': 3, 'negative': 1}),
#               'narrator': defaultdict(int, {'positive': 3, 'negative': 0})}),
#  '94': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 4, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '95': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '96': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int, {'positive': 10, 'negative': 0}),
#               'narrator': defaultdict(int, {'negative': 3, 'positive': 0})}),
#  '97': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'ex_SO': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'doctor': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'medical_prof': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'ED': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '98': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'ED': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'ex_SO': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '99': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 3}),
#               'food': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '100': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '101': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 3, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'family': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '102': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {}),
#  '103': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'therapist': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'medical_prof': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'SO_neutral': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'SO_any': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'reader': defaultdict(int, {'negative': 1, 'positive': 1}),
#               'ED': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'narrator': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'food': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '104': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '105': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'ED': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '106': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 2}),
#               'ex_SO': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'ED': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '107': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {}),
#  '108': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'doctor': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'medical_prof': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'narrator': defaultdict(int, {'negative': 5, 'positive': 0}),
#               'family': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'friend': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '109': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'ED': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'ex_SO': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '110': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 3}),
#               'food': defaultdict(int, {'negative': 3, 'positive': 0})}),
#  '111': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '112': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'positive': 2, 'negative': 3}),
#               'family': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '113': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'ED': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '114': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'reader': defaultdict(int, {'positive': 3, 'negative': 0}),
#               'friend': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'narrator': defaultdict(int, {'positive': 4, 'negative': 5}),
#               'food': defaultdict(int, {'negative': 3, 'positive': 0})}),
#  '115': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int, {'positive': 2, 'negative': 1}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'ED': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '116': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '117': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '118': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'ED': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'family': defaultdict(int, {'negative': 3, 'positive': 0}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '119': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'SO_male': defaultdict(int, {'positive': 4, 'negative': 0}),
#               'SO_any': defaultdict(int, {'positive': 4, 'negative': 0}),
#               'narrator': defaultdict(int, {'negative': 3, 'positive': 0}),
#               'ED': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'food': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '120': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'negative': 3, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'ED': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '121': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'ex_SO': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '122': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'narrator': defaultdict(int, {'negative': 4, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 3, 'positive': 0}),
#               'ex_SO': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '123': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {}),
#  '124': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'therapist': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'medical_prof': defaultdict(int,
#                           {'positive': 1, 'negative': 0})}),
#  '125': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'ED': defaultdict(int, {'negative': 3, 'positive': 0}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '126': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '127': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'SO_neutral': defaultdict(int, {'positive': 2, 'negative': 6}),
#               'SO_any': defaultdict(int, {'positive': 2, 'negative': 6})}),
#  '128': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'ED': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '129': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int, {'positive': 5, 'negative': 2}),
#               'ex_SO': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'nurse': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'medical_prof': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'ED': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '130': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {}),
#  '131': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'ED': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '132': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '133': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'ED': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '134': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 3, 'negative': 1}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '135': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '136': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '137': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 2, 'negative': 2}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'ex_SO': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '138': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {}),
#  '139': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'ED': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '140': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '141': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'doctor': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'medical_prof': defaultdict(int,
#                           {'negative': 1, 'positive': 0})}),
#  '142': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {}),
#  '143': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {}),
#  '144': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 4}),
#               'family': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'SO_male': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'SO_any': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '145': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'SO_female': defaultdict(int, {'positive': 2, 'negative': 1}),
#               'SO_any': defaultdict(int, {'positive': 2, 'negative': 1}),
#               'friend': defaultdict(int, {'positive': 2, 'negative': 1}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'ex_SO': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'ED': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '146': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '147': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 2, 'negative': 1}),
#               'doctor': defaultdict(int, {'positive': 2, 'negative': 1}),
#               'medical_prof': defaultdict(int, {'positive': 2, 'negative': 1}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'ex_SO': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '148': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'negative': 1, 'positive': 1}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '149': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'medical_prof': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'ED': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'ex_SO': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '150': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 2})}),
#  '151': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 2, 'positive': 1}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '152': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'therapist': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'medical_prof': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'ex_SO': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'family': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '153': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 2}),
#               'food': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '154': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int, {'positive': 7, 'negative': 2}),
#               'ED': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '155': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'negative': 4, 'positive': 1}),
#               'ex_SO': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '156': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {}),
#  '157': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'reader': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '158': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'friend': defaultdict(int, {'positive': 3, 'negative': 0}),
#               'ED': defaultdict(int, {'negative': 2, 'positive': 1})}),
#  '159': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {}),
#  '160': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'SO_female': defaultdict(int, {'positive': 5, 'negative': 3}),
#               'SO_any': defaultdict(int, {'positive': 5, 'negative': 3}),
#               'friend': defaultdict(int, {'positive': 5, 'negative': 3}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 1})}),
#  '161': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'ex_SO': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '162': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 2, 'positive': 1}),
#               'nurse': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'medical_prof': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '163': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'ED': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 2, 'negative': 2})}),
#  '164': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 3, 'positive': 0})}),
#  '165': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'negative': 3, 'positive': 2}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'doctor': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'medical_prof': defaultdict(int,
#                           {'negative': 1, 'positive': 0})}),
#  '166': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 2, 'negative': 1}),
#               'SO_male': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'SO_any': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'therapist': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'medical_prof': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'narrator': defaultdict(int, {'negative': 4, 'positive': 0}),
#               'ex_SO': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '167': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'food': defaultdict(int, {'negative': 4, 'positive': 1}),
#               'narrator': defaultdict(int, {'positive': 2, 'negative': 3}),
#               'ED': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '168': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 0}),
# ...
#               'SO_male': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'SO_any': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'ex_SO': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'friend': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '945': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 1})}),
#  '946': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 3}),
#               'ED': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '947': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'positive': 2, 'negative': 1}),
#               'narrator': defaultdict(int, {'negative': 3, 'positive': 0})}),
#  '948': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 3, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '949': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'ED': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '950': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 2, 'negative': 3}),
#               'food': defaultdict(int, {'negative': 6, 'positive': 0})}),
#  '951': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '952': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'ex_SO': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '953': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'ED': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '954': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'doctor': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'medical_prof': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '955': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'nurse': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'medical_prof': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '956': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'SO_female': defaultdict(int, {'positive': 6, 'negative': 0}),
#               'SO_any': defaultdict(int, {'positive': 6, 'negative': 0}),
#               'doctor': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'medical_prof': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '957': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 3}),
#               'food': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '958': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {}),
#  '959': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '960': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'reader': defaultdict(int, {'negative': 2, 'positive': 3}),
#               'narrator': defaultdict(int, {'positive': 2, 'negative': 3}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '961': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'ex_SO': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '962': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'SO_male': defaultdict(int, {'positive': 4, 'negative': 0}),
#               'SO_any': defaultdict(int, {'positive': 4, 'negative': 0}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '963': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '964': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'friend': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 4, 'positive': 0}),
#               'ED': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '965': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'family': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '966': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '967': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 3, 'positive': 0})}),
#  '968': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'therapist': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'medical_prof': defaultdict(int,
#                           {'positive': 1, 'negative': 0})}),
#  '969': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'ex_SO': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'family': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'friend': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '970': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'therapist': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'medical_prof': defaultdict(int,
#                           {'positive': 1, 'negative': 0})}),
#  '971': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '972': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'ex_SO': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'narrator': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '973': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'doctor': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'medical_prof': defaultdict(int, {'positive': 2, 'negative': 1}),
#               'friend': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'negative': 3, 'positive': 1}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'ED': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'therapist': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '974': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {}),
#  '975': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 3, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'family': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'ex_SO': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'ED': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '976': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'ED': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '977': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'ED': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '978': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {}),
#  '979': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 6, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 9, 'positive': 0}),
#               'doctor': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'medical_prof': defaultdict(int,
#                           {'positive': 1, 'negative': 0})}),
#  '980': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '981': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 2, 'negative': 2}),
#               'family': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'ex_SO': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'food': defaultdict(int, {'negative': 3, 'positive': 0}),
#               'ED': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'doctor': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'medical_prof': defaultdict(int,
#                           {'positive': 1, 'negative': 0})}),
#  '982': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 2, 'negative': 1}),
#               'SO_neutral': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'SO_any': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '983': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'negative': 4, 'positive': 0}),
#               'narrator': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'ED': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '984': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '985': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {}),
#  '986': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'friend': defaultdict(int, {'positive': 3, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 2, 'negative': 0})}),
#  '987': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 4, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '988': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'positive': 2, 'negative': 3}),
#               'narrator': defaultdict(int, {'negative': 4, 'positive': 1})}),
#  '989': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 8, 'negative': 2}),
#               'narrator': defaultdict(int, {'positive': 2, 'negative': 0})}),
#  '990': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '991': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'positive': 2, 'negative': 3}),
#               'narrator': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '992': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '993': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '994': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 3, 'negative': 4}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'friend': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'ex_SO': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'ED': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '995': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'family': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '996': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {}),
#  '997': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'negative': 1, 'positive': 1})}),
#  '998': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 4, 'negative': 1})}),
#  '999': defaultdict(<function power_frames.measure_power_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 2}),
#               'food': defaultdict(int, {'negative': 5, 'positive': 0}),
#               'family': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  ...}

# %%
id_persona_agency_dict
# Out:
# {'0': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'therapist': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'medical_prof': defaultdict(int,
#                           {'positive': 1, 'negative': 0})}),
#  '1': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '2': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '3': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '4': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int,
#                           {'positive': 1, 'equal': 1, 'negative': 0}),
#               'reader': defaultdict(int, {'negative': 3, 'positive': 0})}),
#  '5': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'ex_SO': defaultdict(int, {'positive': 2, 'negative': 0})}),
#  '6': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '7': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'narrator': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0})}),
#  '8': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'SO_female': defaultdict(int,
#                           {'equal': 2, 'negative': 2, 'positive': 0}),
#               'SO_any': defaultdict(int,
#                           {'equal': 2, 'negative': 2, 'positive': 0}),
#               'friend': defaultdict(int,
#                           {'equal': 2, 'negative': 2, 'positive': 0}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 1})}),
#  '9': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'SO_male': defaultdict(int,
#                           {'equal': 2, 'positive': 5, 'negative': 5}),
#               'SO_any': defaultdict(int,
#                           {'equal': 2, 'positive': 5, 'negative': 5}),
#               'friend': defaultdict(int,
#                           {'equal': 2, 'positive': 5, 'negative': 5}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '10': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'SO_female': defaultdict(int, {'negative': 1, 'positive': 1}),
#               'SO_any': defaultdict(int, {'negative': 1, 'positive': 1}),
#               'friend': defaultdict(int, {'negative': 1, 'positive': 1})}),
#  '11': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '12': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'family': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '13': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int,
#                           {'positive': 5, 'negative': 2, 'equal': 4}),
#               'friend': defaultdict(int,
#                           {'positive': 1, 'equal': 1, 'negative': 0}),
#               'ex_SO': defaultdict(int, {'negative': 1, 'positive': 1}),
#               'reader': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '14': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '15': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '16': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '17': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int, {'positive': 2, 'negative': 0})}),
#  '18': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'SO_male': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'SO_any': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 2, 'negative': 1})}),
#  '19': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '20': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'food': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'family': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0}),
#               'narrator': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0})}),
#  '21': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int,
#                           {'equal': 2, 'positive': 4, 'negative': 3}),
#               'reader': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '22': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '23': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int,
#                           {'positive': 1, 'equal': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '24': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'ex_SO': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'ED': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '25': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int,
#                           {'equal': 3, 'positive': 2, 'negative': 0})}),
#  '26': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '27': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int,
#                           {'negative': 4, 'positive': 5, 'equal': 1}),
#               'reader': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0})}),
#  '28': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '29': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'reader': defaultdict(int, {'positive': 2, 'negative': 0})}),
#  '30': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '31': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int,
#                           {'negative': 1, 'equal': 1, 'positive': 1}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '32': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'ED': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'SO_male': defaultdict(int, {'positive': 6, 'negative': 2}),
#               'SO_any': defaultdict(int, {'positive': 6, 'negative': 2}),
#               'friend': defaultdict(int, {'positive': 6, 'negative': 2})}),
#  '33': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'doctor': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0}),
#               'medical_prof': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0})}),
#  '34': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '35': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int,
#                           {'equal': 1, 'positive': 10, 'negative': 4})}),
#  '36': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'ED': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'reader': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '37': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '38': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'ED': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int,
#                           {'positive': 1, 'equal': 1, 'negative': 0})}),
#  '39': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '40': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0}),
#               'SO_neutral': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'SO_any': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int,
#                           {'equal': 1, 'positive': 5, 'negative': 0})}),
#  '41': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '42': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '43': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'family': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '44': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'therapist': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'medical_prof': defaultdict(int,
#                           {'positive': 1, 'negative': 0})}),
#  '45': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '46': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '47': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '48': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int,
#                           {'positive': 2, 'negative': 2, 'equal': 2}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '49': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '50': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'doctor': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'medical_prof': defaultdict(int,
#                           {'positive': 1, 'negative': 0})}),
#  '51': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0})}),
#  '52': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '53': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0})}),
#  '54': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'ED': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'family': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '55': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '56': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '57': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'doctor': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'medical_prof': defaultdict(int,
#                           {'positive': 2, 'negative': 0})}),
#  '58': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '59': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'ex_SO': defaultdict(int,
#                           {'negative': 2, 'equal': 3, 'positive': 3}),
#               'friend': defaultdict(int,
#                           {'negative': 2, 'equal': 3, 'positive': 3}),
#               'ED': defaultdict(int,
#                           {'negative': 2, 'equal': 3, 'positive': 3})}),
#  '60': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '61': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '62': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '63': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '64': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '65': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'medical_prof': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'narrator': defaultdict(int, {'positive': 2, 'negative': 0})}),
#  '66': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '67': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'therapist': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'medical_prof': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'food': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '68': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 3, 'negative': 0})}),
#  '69': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '70': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'ED': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'food': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '71': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '72': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '73': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'family': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '74': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'negative': 1, 'positive': 1})}),
#  '75': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'SO_female': defaultdict(int,
#                           {'negative': 1, 'equal': 1, 'positive': 0}),
#               'SO_any': defaultdict(int,
#                           {'negative': 1, 'equal': 1, 'positive': 0}),
#               'narrator': defaultdict(int,
#                           {'positive': 2, 'equal': 1, 'negative': 0}),
#               'ex_SO': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0})}),
#  '76': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'SO_male': defaultdict(int,
#                           {'positive': 1, 'equal': 1, 'negative': 0}),
#               'SO_any': defaultdict(int,
#                           {'positive': 1, 'equal': 1, 'negative': 0})}),
#  '77': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 4, 'negative': 0})}),
#  '78': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '79': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'SO_female': defaultdict(int,
#                           {'positive': 7, 'equal': 3, 'negative': 1}),
#               'SO_any': defaultdict(int,
#                           {'positive': 8, 'equal': 3, 'negative': 1}),
#               'friend': defaultdict(int,
#                           {'positive': 7, 'equal': 3, 'negative': 1}),
#               'narrator': defaultdict(int,
#                           {'equal': 2, 'positive': 1, 'negative': 0}),
#               'reader': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'SO_neutral': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'doctor': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'medical_prof': defaultdict(int,
#                           {'negative': 1, 'positive': 0})}),
#  '80': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '81': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'doctor': defaultdict(int,
#                           {'equal': 1, 'positive': 3, 'negative': 0}),
#               'medical_prof': defaultdict(int,
#                           {'equal': 1, 'positive': 3, 'negative': 0}),
#               'ED': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'family': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int,
#                           {'equal': 1, 'positive': 1, 'negative': 0}),
#               'food': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '82': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int,
#                           {'equal': 1, 'positive': 1, 'negative': 0})}),
#  '83': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 3, 'negative': 1})}),
#  '84': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'food': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '85': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '86': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'SO_neutral': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'SO_any': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'friend': defaultdict(int,
#                           {'positive': 3, 'negative': 5, 'equal': 1})}),
#  '87': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'family': defaultdict(int, {'positive': 3, 'negative': 1})}),
#  '88': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'SO_female': defaultdict(int,
#                           {'positive': 2, 'negative': 3, 'equal': 1}),
#               'SO_any': defaultdict(int,
#                           {'positive': 2, 'negative': 3, 'equal': 1}),
#               'friend': defaultdict(int,
#                           {'positive': 2, 'negative': 3, 'equal': 1})}),
#  '89': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '90': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int,
#                           {'positive': 2, 'equal': 1, 'negative': 0}),
#               'ex_SO': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '91': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '92': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int, {'positive': 8, 'negative': 3}),
#               'narrator': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0})}),
#  '93': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0}),
#               'narrator': defaultdict(int,
#                           {'negative': 3, 'equal': 1, 'positive': 0}),
#               'friend': defaultdict(int, {'positive': 2, 'negative': 0})}),
#  '94': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int,
#                           {'equal': 2, 'positive': 2, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '95': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0}),
#               'reader': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '96': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int,
#                           {'positive': 5, 'negative': 3, 'equal': 1})}),
#  '97': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '98': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '99': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int,
#                           {'equal': 1, 'negative': 1, 'positive': 0})}),
#  '100': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '101': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '102': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '103': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'therapist': defaultdict(int, {'negative': 1, 'positive': 2}),
#               'medical_prof': defaultdict(int, {'negative': 1, 'positive': 2}),
#               'ED': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0}),
#               'SO_neutral': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0}),
#               'SO_any': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0}),
#               'reader': defaultdict(int, {'positive': 2, 'negative': 0})}),
#  '104': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '105': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int,
#                           {'equal': 1, 'positive': 3, 'negative': 0})}),
#  '106': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int,
#                           {'equal': 1, 'positive': 1, 'negative': 0})}),
#  '107': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '108': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'doctor': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'medical_prof': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'family': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '109': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 2, 'positive': 0})}),
#  '110': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '111': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '112': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'family': defaultdict(int,
#                           {'negative': 1, 'equal': 1, 'positive': 0})}),
#  '113': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '114': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 2}),
#               'friend': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'narrator': defaultdict(int,
#                           {'negative': 1, 'equal': 1, 'positive': 1})}),
#  '115': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int, {'positive': 2, 'negative': 1}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '116': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '117': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '118': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'ED': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'doctor': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0}),
#               'medical_prof': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '119': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'SO_male': defaultdict(int,
#                           {'negative': 3, 'positive': 5, 'equal': 1}),
#               'SO_any': defaultdict(int,
#                           {'negative': 3, 'positive': 5, 'equal': 1}),
#               'narrator': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0})}),
#  '120': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '121': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'ex_SO': defaultdict(int, {'positive': 2, 'negative': 0})}),
#  '122': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '123': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '124': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'therapist': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'medical_prof': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'reader': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0})}),
#  '125': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 2, 'negative': 0})}),
#  '126': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '127': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'SO_neutral': defaultdict(int,
#                           {'positive': 5, 'equal': 2, 'negative': 2}),
#               'SO_any': defaultdict(int,
#                           {'positive': 5, 'equal': 2, 'negative': 2})}),
#  '128': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '129': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int, {'negative': 2, 'positive': 5}),
#               'ex_SO': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '130': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '131': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '132': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '133': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'ED': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '134': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0}),
#               'family': defaultdict(int,
#                           {'negative': 1, 'equal': 1, 'positive': 1})}),
#  '135': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '136': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '137': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int,
#                           {'positive': 2, 'negative': 1, 'equal': 1}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '138': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '139': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '140': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '141': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '142': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '143': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '144': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'family': defaultdict(int, {'positive': 2, 'negative': 0})}),
#  '145': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'SO_female': defaultdict(int,
#                           {'positive': 4, 'equal': 1, 'negative': 0}),
#               'SO_any': defaultdict(int,
#                           {'positive': 4, 'equal': 1, 'negative': 0}),
#               'friend': defaultdict(int,
#                           {'positive': 4, 'equal': 1, 'negative': 0})}),
#  '146': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '147': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 3, 'negative': 0}),
#               'doctor': defaultdict(int, {'positive': 3, 'negative': 0}),
#               'medical_prof': defaultdict(int, {'positive': 3, 'negative': 0}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '148': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'negative': 1, 'positive': 1}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '149': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'medical_prof': defaultdict(int,
#                           {'negative': 1, 'positive': 0})}),
#  '150': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 2, 'negative': 0})}),
#  '151': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '152': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'therapist': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'medical_prof': defaultdict(int,
#                           {'positive': 1, 'negative': 0})}),
#  '153': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'doctor': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'medical_prof': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'family': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '154': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int,
#                           {'positive': 13, 'equal': 1, 'negative': 1})}),
#  '155': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int,
#                           {'equal': 2, 'positive': 5, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '156': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '157': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 3, 'negative': 0})}),
#  '158': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'friend': defaultdict(int, {'negative': 1, 'positive': 1})}),
#  '159': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '160': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'SO_female': defaultdict(int, {'positive': 5, 'negative': 5}),
#               'SO_any': defaultdict(int, {'positive': 5, 'negative': 5}),
#               'friend': defaultdict(int, {'positive': 5, 'negative': 5}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '161': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '162': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'nurse': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'medical_prof': defaultdict(int,
#                           {'positive': 1, 'negative': 0})}),
#  '163': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'ED': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '164': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '165': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '166': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int,
#                           {'positive': 1, 'equal': 1, 'negative': 0}),
#               'SO_male': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0}),
#               'SO_any': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0}),
#               'narrator': defaultdict(int,
#                           {'equal': 2, 'positive': 0, 'negative': 0}),
#               'doctor': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0}),
#               'medical_prof': defaultdict(int,
#                           {'equal': 1, 'positive': 1, 'negative': 1}),
#               'therapist': defaultdict(int, {'positive': 1, 'negative': 1})}),
#  '167': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'food': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'narrator': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0})}),
#  '168': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '169': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int,
#                           {'equal': 4, 'positive': 3, 'negative': 0}),
#               'family': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '170': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '171': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'family': defaultdict(int, {'negative': 2, 'positive': 3}),
#               'reader': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '172': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'family': defaultdict(int, {'positive': 2, 'negative': 0})}),
#  '173': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'family': defaultdict(int, {'negative': 1, 'positive': 1}),
#               'food': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '174': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'SO_neutral': defaultdict(int,
#                           {'equal': 3, 'negative': 1, 'positive': 0}),
#               'SO_any': defaultdict(int,
#                           {'equal': 3, 'negative': 1, 'positive': 0})}),
#  '175': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '176': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'family': defaultdict(int, {'positive': 2, 'negative': 1}),
#               'reader': defaultdict(int, {'positive': 4, 'negative': 6})}),
#  '177': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '178': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '179': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'SO_female': defaultdict(int,
#                           {'positive': 5, 'negative': 1, 'equal': 2}),
#               'SO_any': defaultdict(int,
#                           {'positive': 5, 'negative': 1, 'equal': 2}),
#               'friend': defaultdict(int,
#                           {'positive': 5, 'negative': 1, 'equal': 2})}),
#  '180': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 3, 'negative': 1})}),
#  '181': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 1}),
#               'food': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'reader': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '182': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'doctor': defaultdict(int,
#                           {'negative': 1, 'equal': 1, 'positive': 0}),
#               'medical_prof': defaultdict(int,
#                           {'negative': 1, 'equal': 1, 'positive': 0}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '183': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'doctor': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'medical_prof': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'family': defaultdict(int,
#                           {'positive': 2, 'negative': 1, 'equal': 1}),
#               'friend': defaultdict(int,
#                           {'negative': 1, 'equal': 1, 'positive': 1}),
#               'reader': defaultdict(int,
#                           {'equal': 2, 'positive': 0, 'negative': 0}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '184': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'ex_SO': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '185': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '186': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '187': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '188': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'doctor': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'medical_prof': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '189': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int,
#                           {'equal': 1, 'positive': 1, 'negative': 0})}),
#  '190': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '191': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '192': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int,
#                           {'positive': 2, 'equal': 1, 'negative': 0})}),
#  '193': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'narrator': defaultdict(int,
#                           {'equal': 1, 'negative': 1, 'positive': 0})}),
#  '194': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int,
#                           {'equal': 1, 'positive': 4, 'negative': 0}),
#               'ED': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '195': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '196': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'SO_male': defaultdict(int,
#                           {'positive': 16, 'negative': 5, 'equal': 1}),
#               'SO_any': defaultdict(int,
#                           {'positive': 16, 'negative': 5, 'equal': 1}),
#               'reader': defaultdict(int, {'positive': 2, 'negative': 0})}),
#  '197': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
# ...
#  '929': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 2, 'negative': 0})}),
#  '930': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '931': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '932': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 2})}),
#  '933': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '934': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 1})}),
#  '935': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int,
#                           {'equal': 2, 'positive': 6, 'negative': 1})}),
#  '936': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 2, 'negative': 0})}),
#  '937': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'doctor': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'medical_prof': defaultdict(int,
#                           {'positive': 1, 'negative': 0})}),
#  '938': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 6, 'negative': 0}),
#               'reader': defaultdict(int,
#                           {'equal': 1, 'positive': 3, 'negative': 0})}),
#  '939': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '940': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'negative': 1, 'positive': 1}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '941': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '942': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int, {'positive': 2, 'negative': 0})}),
#  '943': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '944': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'SO_male': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'SO_any': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'friend': defaultdict(int,
#                           {'negative': 1, 'positive': 1, 'equal': 1}),
#               'ex_SO': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '945': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '946': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'family': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '947': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'food': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '948': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0}),
#               'SO_male': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'SO_any': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '949': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int,
#                           {'equal': 1, 'positive': 1, 'negative': 0}),
#               'ED': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '950': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'family': defaultdict(int, {'positive': 2, 'negative': 0})}),
#  '951': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int,
#                           {'negative': 1, 'equal': 1, 'positive': 0})}),
#  '952': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '953': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '954': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'doctor': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'medical_prof': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '955': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int,
#                           {'positive': 2, 'equal': 1, 'negative': 0}),
#               'nurse': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'medical_prof': defaultdict(int,
#                           {'positive': 1, 'negative': 0})}),
#  '956': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'SO_female': defaultdict(int, {'positive': 3, 'negative': 2}),
#               'SO_any': defaultdict(int, {'positive': 3, 'negative': 2})}),
#  '957': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '958': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '959': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '960': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int,
#                           {'negative': 5, 'positive': 4, 'equal': 1}),
#               'reader': defaultdict(int,
#                           {'negative': 1, 'positive': 2, 'equal': 2}),
#               'narrator': defaultdict(int,
#                           {'positive': 1, 'negative': 1, 'equal': 1})}),
#  '961': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'friend': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '962': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'SO_male': defaultdict(int,
#                           {'positive': 3, 'negative': 2, 'equal': 1}),
#               'SO_any': defaultdict(int,
#                           {'positive': 3, 'negative': 2, 'equal': 1})}),
#  '963': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '964': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 1, 'positive': 1}),
#               'friend': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '965': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 1, 'negative': 1})}),
#  '966': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'friend': defaultdict(int, {'positive': 1, 'negative': 1})}),
#  '967': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '968': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int,
#                           {'positive': 1, 'equal': 1, 'negative': 0})}),
#  '969': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'ex_SO': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'narrator': defaultdict(int, {'negative': 2, 'positive': 0}),
#               'family': defaultdict(int, {'negative': 1, 'positive': 1})}),
#  '970': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'therapist': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'medical_prof': defaultdict(int,
#                           {'positive': 1, 'negative': 0})}),
#  '971': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '972': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '973': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'doctor': defaultdict(int, {'positive': 3, 'negative': 0}),
#               'medical_prof': defaultdict(int, {'positive': 3, 'negative': 0}),
#               'friend': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '974': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '975': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'SO_male': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'SO_any': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'friend': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'narrator': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0}),
#               'family': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '976': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 2, 'negative': 0}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '977': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '978': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '979': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'doctor': defaultdict(int, {'negative': 1, 'positive': 2}),
#               'medical_prof': defaultdict(int, {'negative': 1, 'positive': 2}),
#               'narrator': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0}),
#               'family': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '980': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '981': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'family': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'ex_SO': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '982': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'SO_neutral': defaultdict(int,
#                           {'positive': 1, 'equal': 1, 'negative': 0}),
#               'SO_any': defaultdict(int,
#                           {'positive': 1, 'equal': 1, 'negative': 0}),
#               'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'family': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '983': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0}),
#               'food': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0})}),
#  '984': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '985': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '986': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'reader': defaultdict(int, {'negative': 1, 'positive': 0}),
#               'friend': defaultdict(int, {'positive': 3, 'negative': 1}),
#               'narrator': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0})}),
#  '987': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '988': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '989': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int,
#                           {'equal': 1, 'negative': 3, 'positive': 7}),
#               'narrator': defaultdict(int, {'negative': 1, 'positive': 2})}),
#  '990': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '991': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'food': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '992': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'reader': defaultdict(int,
#                           {'equal': 1, 'positive': 0, 'negative': 0})}),
#  '993': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '994': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int,
#                           {'positive': 1, 'equal': 1, 'negative': 2}),
#               'reader': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  '995': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int,
#                           {'positive': 1, 'equal': 1, 'negative': 0}),
#               'family': defaultdict(int, {'negative': 1, 'positive': 0})}),
#  '996': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '997': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {}),
#  '998': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'family': defaultdict(int, {'positive': 3, 'negative': 0})}),
#  '999': defaultdict(<function power_frames.measure_agency_per_document.<locals>.<lambda>()>,
#              {'narrator': defaultdict(int, {'positive': 1, 'negative': 0}),
#               'friend': defaultdict(int, {'positive': 1, 'negative': 0})}),
#  ...}

# %%
persona_counts_power = defaultdict(int)
for _id, _persona_power_dict in id_persona_power_dict.items():
    for _persona in _persona_power_dict.keys():
        persona_counts_power[_persona] += _persona_power_dict[_persona]['positive'] + _persona_power_dict[_persona]['negative']

persona_counts_agency = defaultdict(int)
for _id, _persona_agency_dict in id_persona_agency_dict.items():
    for _persona in _persona_agency_dict.keys():
        persona_counts_agency[_persona] += _persona_agency_dict[_persona]['positive'] + _persona_agency_dict[_persona]['negative']

# %%
# save persona counts
with open(folder + 'persona_counts_power.json', 'w') as f:
    json.dump(persona_counts_power, f, indent=4)
with open(folder + 'persona_counts_agency.json', 'w') as f:
    json.dump(persona_counts_agency, f, indent=4)

# %%
persona_scores_dict = defaultdict(list)
for _id, _persona_score_dict in id_persona_score_dict.items():
    for _persona, _score in _persona_score_dict.items():
        persona_scores_dict[_persona].append(_score)

persona_score_dict = {_persona: np.mean(_scores) for _persona, _scores in persona_scores_dict.items()}

# %%
persona_agency_scores_dict = defaultdict(list)
for _id, _persona_agency_score_dict in id_persona_agency_score_dict.items():
    for _persona, _score in _persona_agency_score_dict.items():
        persona_agency_scores_dict[_persona].append(_score)

persona_agency_score_dict = {_persona: np.mean(_scores) for _persona, _scores in persona_agency_scores_dict.items()}

# %%
print('Power Scores:')
for _persona, _score in persona_score_dict.items():
    print(_persona, round(_score, 2), '(n=' + str(persona_counts_power[_persona]) + ')')
# Out:
# Power Scores:
# food -0.62 (n=5298)
# therapist -0.11 (n=324)
# medical_prof -0.1 (n=1263)
# narrator -0.32 (n=14008)
# reader 0.42 (n=4053)
# ex_SO -0.54 (n=1513)
# family 0.08 (n=3527)
# SO_female 0.14 (n=403)
# SO_any 0.14 (n=1491)
# friend -0.0 (n=2015)
# SO_male 0.2 (n=780)
# ED -0.58 (n=2109)
# doctor -0.13 (n=778)
# SO_neutral -0.03 (n=308)
# nurse -0.04 (n=95)

# %%
print('Agency Scores:')
for _persona, _score in persona_agency_score_dict.items():
    print(_persona, round(_score, 2), '(n=' + str(persona_counts_agency[_persona]) + ')')
# Out:
# Agency Scores:
# food 0.29 (n=652)
# therapist 0.36 (n=371)
# medical_prof 0.41 (n=1065)
# reader 0.13 (n=3458)
# narrator 0.15 (n=3906)
# ex_SO 0.41 (n=500)
# family 0.35 (n=3619)
# SO_female 0.11 (n=418)
# SO_any 0.28 (n=1692)
# friend 0.3 (n=2029)
# SO_male 0.32 (n=946)
# ED 0.54 (n=574)
# doctor 0.43 (n=559)
# SO_neutral 0.3 (n=328)
# nurse 0.51 (n=52)

# %%
# save score dicts
with open(folder + 'persona_power_score_dict.json', 'w') as f:
    json.dump(persona_score_dict, f, indent=4)
with open(folder + 'persona_agency_score_dict.json', 'w') as f:
    json.dump(persona_agency_score_dict, f, indent=4)

# %% [markdown]
# <br><br><br><br>
#
# # Examine the verb coverage
#
# Print the verbs that were most frequently matched to the lexicon

# %%
id_nsubj_verb_count_dict
# Out:
# {'0': defaultdict(int,
#              {('food', 'have'): 1,
#               ('therapist', 'recommend'): 1,
#               ('medical_prof', 'recommend'): 1}),
#  '1': defaultdict(int,
#              {('narrator', 'be'): 1,
#               ('reader', 'know'): 1,
#               ('narrator', 'give'): 1,
#               ('SO_male', 'fell'): 1,
#               ('SO_any', 'fell'): 1,
#               ('friend', 'fell'): 1}),
#  '2': defaultdict(int, {}),
#  '3': defaultdict(int, {('ED', 'be'): 1, ('narrator', 'be'): 1}),
#  '4': defaultdict(int,
#              {('narrator', 'hurt'): 1,
#               ('narrator', 'feel'): 1,
#               ('reader', 'regret'): 1,
#               ('reader', 'have'): 1,
#               ('reader', 'want'): 1,
#               ('narrator', 'be'): 1}),
#  '5': defaultdict(int, {('ex_SO', 'do'): 1, ('ex_SO', 'scream'): 1}),
#  '6': defaultdict(int, {}),
#  '7': defaultdict(int,
#              {('family', 'be'): 3,
#               ('family', 'decide'): 1,
#               ('family', 'talks'): 1,
#               ('family', 'make'): 1,
#               ('narrator', 'watch'): 1,
#               ('family', 'always'): 1,
#               ('family', '’s'): 1,
#               ('reader', 'be'): 1}),
#  '8': defaultdict(int,
#              {('SO_female', 'go'): 1,
#               ('SO_any', 'go'): 1,
#               ('friend', 'go'): 1,
#               ('SO_female', 'find'): 1,
#               ('SO_any', 'find'): 1,
#               ('friend', 'find'): 1,
#               ('SO_female', 'seem'): 1,
#               ('SO_any', 'seem'): 1,
#               ('friend', 'seem'): 1,
#               ('SO_female', 'want'): 1,
#               ('SO_any', 'want'): 1,
#               ('friend', 'want'): 1,
#               ('SO_female', 'be'): 1,
#               ('SO_any', 'be'): 1,
#               ('friend', 'be'): 1,
#               ('reader', 'recover'): 1,
#               ('narrator', 'suffer'): 1,
#               ('narrator', 'be'): 1,
#               ('reader', 'wish'): 1,
#               ('narrator', 'say'): 1,
#               ('reader', 'be'): 1}),
#  '9': defaultdict(int,
#              {('SO_male', 'struggle'): 1,
#               ('SO_any', 'struggle'): 1,
#               ('friend', 'struggle'): 1,
#               ('SO_male', 'move'): 1,
#               ('SO_any', 'move'): 1,
#               ('friend', 'move'): 1,
#               ('SO_male', 'eat'): 1,
#               ('SO_any', 'eat'): 1,
#               ('friend', 'eat'): 1,
#               ('SO_male', 'have'): 1,
#               ('SO_any', 'have'): 1,
#               ('friend', 'have'): 1,
#               ('SO_male', 'trust'): 1,
#               ('SO_any', 'trust'): 1,
#               ('friend', 'trust'): 1,
#               ('SO_male', 'go'): 1,
#               ('SO_any', 'go'): 1,
#               ('friend', 'go'): 1,
#               ('SO_male', 'become'): 1,
#               ('SO_any', 'become'): 1,
#               ('friend', 'become'): 1,
#               ('narrator', 'want'): 1,
#               ('SO_male', 'dismiss'): 1,
#               ('SO_any', 'dismiss'): 1,
#               ('friend', 'dismiss'): 1,
#               ('SO_male', 'want'): 1,
#               ('SO_any', 'want'): 1,
#               ('friend', 'want'): 1,
#               ('SO_male', 'tell'): 1,
#               ('SO_any', 'tell'): 1,
#               ('friend', 'tell'): 1,
#               ('SO_male', 'be'): 2,
#               ('SO_any', 'be'): 2,
#               ('friend', 'be'): 2,
#               ('SO_male', 'realize'): 1,
#               ('SO_any', 'realize'): 1,
#               ('friend', 'realize'): 1,
#               ('SO_male', 'need'): 1,
#               ('SO_any', 'need'): 1,
#               ('friend', 'need'): 1}),
#  '10': defaultdict(int,
#              {('SO_female', 'have'): 1,
#               ('SO_any', 'have'): 1,
#               ('friend', 'have'): 1,
#               ('SO_female', 'take'): 1,
#               ('SO_any', 'take'): 1,
#               ('friend', 'take'): 1}),
#  '11': defaultdict(int, {}),
#  '12': defaultdict(int, {('reader', 'say'): 1, ('family', 'worry'): 1}),
#  '13': defaultdict(int,
#              {('family', 'get'): 1,
#               ('friend', 'complain'): 1,
#               ('friend', 'go'): 1,
#               ('ex_SO', 'sit'): 1,
#               ('ex_SO', 'finish'): 1,
#               ('reader', 'need'): 1,
#               ('reader', 'have'): 1,
#               ('reader', 'be'): 2,
#               ('family', 'wrong'): 1,
#               ('family', 'think'): 1,
#               ('family', 'have'): 1,
#               ('family', 'mumble'): 1,
#               ('family', 'say'): 2,
#               ('family', 'cry'): 2,
#               ('family', 'feel'): 1,
#               ('family', 'like'): 1,
#               ('family', 'trust'): 1,
#               ('family', '’s'): 1}),
#  '14': defaultdict(int, {}),
#  '15': defaultdict(int, {}),
#  '16': defaultdict(int, {}),
#  '17': defaultdict(int,
#              {('food', 'be'): 1,
#               ('friend', 'reassure'): 1,
#               ('friend', 'say'): 1}),
#  '18': defaultdict(int,
#              {('SO_male', 'beg'): 1,
#               ('SO_any', 'beg'): 1,
#               ('narrator', 'nauseous'): 1,
#               ('narrator', 'be'): 1,
#               ('narrator', 'force'): 1,
#               ('narrator', 'say'): 1,
#               ('reader', '’re'): 1,
#               ('narrator', 'keep'): 1}),
#  '19': defaultdict(int, {}),
#  '20': defaultdict(int,
#              {('reader', 'think'): 1,
#               ('food', 'cause'): 1,
#               ('family', 'notice'): 1,
#               ('narrator', 'feel'): 1}),
#  '21': defaultdict(int,
#              {('family', 'go'): 2,
#               ('family', 'do'): 1,
#               ('family', 'lay'): 1,
#               ('family', 'reach'): 1,
#               ('family', 'be'): 1,
#               ('family', 'eat'): 1,
#               ('family', 'have'): 3,
#               ('family', 'anxious'): 1,
#               ('reader', 'need'): 1,
#               ('reader', 'want'): 1,
#               ('narrator', 'think'): 1}),
#  '22': defaultdict(int, {('narrator', 'be'): 1}),
#  '23': defaultdict(int,
#              {('narrator', 'be'): 1,
#               ('family', 'ask'): 1,
#               ('narrator', 'eat'): 1,
#               ('family', 'be'): 1,
#               ('family', 'leave'): 1}),
#  '24': defaultdict(int,
#              {('ex_SO', 'end'): 1,
#               ('ED', 'end'): 1,
#               ('narrator', 'take'): 1,
#               ('reader', 'deal'): 1}),
#  '25': defaultdict(int,
#              {('family', 'find'): 1,
#               ('narrator', 'be'): 1,
#               ('family', 'go'): 1,
#               ('family', 'be'): 1,
#               ('family', 'say'): 1,
#               ('family', 'sound'): 1,
#               ('family', 'understand'): 1}),
#  '26': defaultdict(int,
#              {('reader', 'be'): 1,
#               ('reader', 'message'): 1,
#               ('reader', 'need'): 1}),
#  '27': defaultdict(int,
#              {('family', 'have'): 2,
#               ('family', 'refuse'): 1,
#               ('family', 'make'): 1,
#               ('family', 'say'): 1,
#               ('reader', 'diet'): 1,
#               ('reader', 'lose'): 1,
#               ('family', 'want'): 1,
#               ('family', 'tell'): 2,
#               ('family', 'feel'): 1,
#               ('family', 'see'): 1}),
#  '28': defaultdict(int, {('family', 'stop'): 1, ('narrator', 'die'): 1}),
#  '29': defaultdict(int,
#              {('family', 'tell'): 1,
#               ('family', 'ask'): 1,
#               ('reader', 'eat'): 2}),
#  '30': defaultdict(int, {}),
#  '31': defaultdict(int,
#              {('food', 'want'): 1,
#               ('narrator', 'starve'): 1,
#               ('food', 'leave'): 1,
#               ('food', 'get'): 1,
#               ('food', "'re"): 1}),
#  '32': defaultdict(int,
#              {('ED', 'start'): 1,
#               ('SO_male', 'make'): 1,
#               ('SO_any', 'make'): 1,
#               ('friend', 'make'): 1,
#               ('therapist', 'belive'): 1,
#               ('medical_prof', 'belive'): 1,
#               ('SO_male', 'keep'): 1,
#               ('SO_any', 'keep'): 1,
#               ('friend', 'keep'): 1,
#               ('narrator', 'be'): 1,
#               ('SO_male', 'bring'): 1,
#               ('SO_any', 'bring'): 1,
#               ('friend', 'bring'): 1,
#               ('SO_male', 'say'): 3,
#               ('SO_any', 'say'): 3,
#               ('friend', 'say'): 3,
#               ('SO_male', 'want'): 1,
#               ('SO_any', 'want'): 1,
#               ('friend', 'want'): 1,
#               ('SO_male', 'do'): 1,
#               ('SO_any', 'do'): 1,
#               ('friend', 'do'): 1}),
#  '33': defaultdict(int, {('doctor', 'feel'): 1, ('medical_prof', 'feel'): 1}),
#  '34': defaultdict(int, {('reader', 'want'): 1}),
#  '35': defaultdict(int,
#              {('friend', 'struggle'): 1,
#               ('friend', 'start'): 1,
#               ('friend', 'seem'): 3,
#               ('friend', 'make'): 1,
#               ('friend', 'talk'): 1,
#               ('friend', "'s"): 1,
#               ('friend', 'overlook'): 1,
#               ('friend', 'eat'): 3,
#               ('friend', 'claim'): 2,
#               ('friend', 'give'): 1,
#               ('friend', 'be'): 1,
#               ('friend', 'try'): 1}),
#  '36': defaultdict(int,
#              {('ED', 'eat'): 1,
#               ('narrator', 'talk'): 1,
#               ('reader', 'be'): 1,
#               ('reader', 'want'): 1}),
#  '37': defaultdict(int, {}),
#  '38': defaultdict(int,
#              {('ED', 'eat'): 1,
#               ('narrator', 'control'): 1,
#               ('narrator', 'feel'): 1}),
#  '39': defaultdict(int, {}),
#  '40': defaultdict(int,
#              {('narrator', 'awkward'): 1,
#               ('reader', 'read'): 1,
#               ('SO_neutral', 'recover'): 1,
#               ('SO_any', 'recover'): 1,
#               ('narrator', 'feel'): 1,
#               ('narrator', 'continue'): 1,
#               ('narrator', 'upset'): 2,
#               ('narrator', 'be'): 1,
#               ('narrator', 'tell'): 1,
#               ('narrator', 'talk'): 1}),
#  '41': defaultdict(int, {}),
#  '42': defaultdict(int, {('narrator', 'be'): 1}),
#  '43': defaultdict(int, {('narrator', 'say'): 1, ('family', 'weep'): 1}),
#  '44': defaultdict(int,
#              {('narrator', 'afraid'): 1,
#               ('narrator', 'handle'): 1,
#               ('therapist', 'give'): 1,
#               ('medical_prof', 'give'): 1,
#               ('narrator', 'gain'): 1}),
#  '45': defaultdict(int, {('reader', 'cop'): 1}),
#  '46': defaultdict(int, {}),
#  '47': defaultdict(int, {('reader', 'help'): 1, ('narrator', 'cope'): 1}),
#  '48': defaultdict(int,
#              {('friend', 'be'): 2,
#               ('friend', 'get'): 1,
#               ('reader', 'name'): 1,
#               ('friend', 'have'): 1,
#               ('narrator', 'wrong'): 1,
#               ('friend', 'reveal'): 1,
#               ('friend', 'suffer'): 1,
#               ('friend', 'feel'): 2,
#               ('friend', "'s"): 1}),
#  '49': defaultdict(int, {('narrator', 'be'): 1}),
#  '50': defaultdict(int,
#              {('doctor', 'advise'): 1, ('medical_prof', 'advise'): 1}),
#  '51': defaultdict(int, {('narrator', 'feel'): 1, ('family', 'be'): 1}),
#  '52': defaultdict(int, {('family', 'love'): 1, ('narrator', 'be'): 1}),
#  '53': defaultdict(int, {('food', 'be'): 1, ('narrator', 'go'): 1}),
#  '54': defaultdict(int, {('ED', 'get'): 1, ('family', 'take'): 1}),
#  '55': defaultdict(int, {('narrator', 'be'): 1}),
#  '56': defaultdict(int, {}),
#  '57': defaultdict(int,
#              {('reader', 'have'): 1,
#               ('doctor', 'suggest'): 1,
#               ('medical_prof', 'suggest'): 1,
#               ('doctor', 'say'): 1,
#               ('medical_prof', 'say'): 1}),
#  '58': defaultdict(int, {}),
#  '59': defaultdict(int,
#              {('ex_SO', 'skip'): 1,
#               ('friend', 'skip'): 1,
#               ('ED', 'skip'): 1,
#               ('ex_SO', 'be'): 1,
#               ('friend', 'be'): 1,
#               ('ED', 'be'): 1,
#               ('ex_SO', 'need'): 1,
#               ('friend', 'need'): 1,
#               ('ED', 'need'): 1,
#               ('ex_SO', 'go'): 1,
#               ('friend', 'go'): 1,
#               ('ED', 'go'): 1,
#               ('ex_SO', 'eat'): 2,
#               ('friend', 'eat'): 2,
#               ('ED', 'eat'): 2,
#               ('ex_SO', 'refuse'): 1,
#               ('friend', 'refuse'): 1,
#               ('ED', 'refuse'): 1,
#               ('ex_SO', 'lose'): 1,
#               ('friend', 'lose'): 1,
#               ('ED', 'lose'): 1,
#               ('ex_SO', 's'): 1,
#               ('friend', 's'): 1,
#               ('ED', 's'): 1,
#               ('ex_SO', 'mention'): 1,
#               ('friend', 'mention'): 1,
#               ('ED', 'mention'): 1}),
#  '60': defaultdict(int, {}),
#  '61': defaultdict(int, {('food', 'be'): 1}),
#  '62': defaultdict(int, {}),
#  '63': defaultdict(int, {('narrator', 'happy'): 1}),
#  '64': defaultdict(int,
#              {('narrator', 'want'): 1, ('narrator', 'suicidal'): 1}),
#  '65': defaultdict(int, {('medical_prof', 'know'): 1, ('narrator', 'eat'): 2}),
#  '66': defaultdict(int,
#              {('family', 'be'): 1,
#               ('reader', 'eat'): 1,
#               ('narrator', 'comment'): 1,
#               ('narrator', 'be'): 2,
#               ('food', 'be'): 3,
#               ('narrator', 'relapse'): 1}),
#  '67': defaultdict(int,
#              {('therapist', 'tell'): 1,
#               ('medical_prof', 'tell'): 1,
#               ('food', 'fit'): 1}),
#  '68': defaultdict(int,
#              {('family', 'say'): 1,
#               ('family', 'get'): 1,
#               ('family', 'eat'): 1}),
#  '69': defaultdict(int, {}),
#  '70': defaultdict(int,
#              {('ED', 'be'): 1,
#               ('reader', 'eat'): 1,
#               ('narrator', 'binge'): 1,
#               ('ED', 'allow'): 1,
#               ('narrator', 'eat'): 1,
#               ('narrator', 'allow'): 1,
#               ('food', 'allow'): 1}),
#  '71': defaultdict(int, {}),
#  '72': defaultdict(int, {('ED', 'be'): 1}),
#  '73': defaultdict(int,
#              {('narrator', 'starve'): 1,
#               ('narrator', 'unnecessary'): 1,
#               ('family', 'unnecessary'): 1,
#               ('ED', 'be'): 1,
#               ('family', 'say'): 1,
#               ('narrator', 'nervous'): 1}),
#  '74': defaultdict(int,
#              {('food', 'be'): 1,
#               ('family', 'have'): 1,
#               ('family', 'be'): 1,
#               ('family', 'turn'): 1}),
#  '75': defaultdict(int,
#              {('SO_female', 'have'): 1,
#               ('SO_any', 'have'): 1,
#               ('ex_SO', 'be'): 1,
#               ('narrator', 'pass'): 1,
#               ('narrator', 'feel'): 1,
#               ('narrator', 'say'): 1,
#               ('SO_female', 'live'): 1,
#               ('SO_any', 'live'): 1,
#               ('ex_SO', 'live'): 1,
#               ('family', 'be'): 1}),
#  '76': defaultdict(int,
#              {('friend', 'tell'): 1,
#               ('SO_male', 'take'): 1,
#               ('SO_any', 'take'): 1,
#               ('SO_male', 'agree'): 1,
#               ('SO_any', 'agree'): 1}),
#  '77': defaultdict(int,
#              {('family', 'claim'): 1,
#               ('family', 'take'): 1,
#               ('family', 'accuse'): 1,
#               ('family', 'think'): 1}),
#  '78': defaultdict(int, {('friend', 'get'): 1}),
#  '79': defaultdict(int,
#              {('SO_female', 'show'): 1,
#               ('SO_any', 'show'): 1,
#               ('friend', 'show'): 1,
#               ('SO_female', 'ai'): 3,
#               ('SO_any', 'ai'): 3,
#               ('friend', 'ai'): 3,
#               ('SO_female', 'make'): 1,
#               ('SO_any', 'make'): 1,
#               ('friend', 'make'): 1,
#               ('SO_female', 'eat'): 1,
#               ('SO_any', 'eat'): 1,
#               ('friend', 'eat'): 1,
#               ('SO_female', 'look'): 1,
#               ('SO_any', 'look'): 1,
#               ('friend', 'look'): 1,
#               ('SO_female', 'go'): 1,
#               ('SO_any', 'go'): 1,
#               ('friend', 'go'): 1,
#               ('SO_female', 'respond'): 1,
#               ('SO_any', 'respond'): 1,
#               ('friend', 'respond'): 1,
#               ('SO_female', 'communicate'): 1,
#               ('SO_any', 'communicate'): 1,
#               ('friend', 'communicate'): 1,
#               ('SO_female', 'be'): 1,
#               ('SO_any', 'be'): 1,
#               ('friend', 'be'): 1,
#               ('narrator', 'like'): 1,
#               ('narrator', "'re"): 1,
#               ('SO_female', 'laugh'): 1,
#               ('SO_any', 'laugh'): 1,
#               ('friend', 'laugh'): 1,
#               ('SO_female', "'s"): 1,
#               ('SO_any', "'s"): 1,
#               ('friend', "'s"): 1,
#               ('narrator', 'get'): 1,
#               ('reader', 'get'): 1,
#               ('reader', 'do'): 1,
#               ('SO_neutral', 'do'): 1,
#               ('SO_any', 'do'): 1,
#               ('narrator', 'mention'): 1,
#               ('SO_female', 'wear'): 1,
#               ('SO_any', 'wear'): 1,
#               ('friend', 'wear'): 1,
#               ('SO_female', 'choose'): 1,
#               ('SO_any', 'choose'): 1,
#               ('friend', 'choose'): 1,
#               ('SO_female', 'have'): 1,
#               ('SO_any', 'have'): 1,
#               ('friend', 'have'): 1,
#               ('doctor', 'have'): 1,
#               ('medical_prof', 'have'): 1}),
#  '80': defaultdict(int, {('narrator', 'reliant'): 1}),
#  '81': defaultdict(int,
#              {('reader', 'get'): 2,
#               ('reader', 'gon'): 1,
#               ('narrator', 'be'): 1,
#               ('food', 'be'): 1,
#               ('narrator', 'happy'): 1,
#               ('doctor', 'weigh'): 1,
#               ('medical_prof', 'weigh'): 1,
#               ('ED', 'happen'): 1,
#               ('family', 'give'): 1,
#               ('doctor', 'tell'): 2,
#               ('medical_prof', 'tell'): 2,
#               ('doctor', 'say'): 1,
#               ('medical_prof', 'say'): 1,
#               ('narrator', 'feel'): 1,
#               ('food', 'make'): 1,
#               ('narrator', 'loose'): 1}),
#  '82': defaultdict(int,
#              {('reader', 'be'): 1,
#               ('reader', 'look'): 1,
#               ('reader', 'battle'): 1}),
#  '83': defaultdict(int,
#              {('reader', 'restrict'): 1,
#               ('reader', 'eat'): 1,
#               ('reader', 'have'): 1,
#               ('reader', 'make'): 1}),
#  '84': defaultdict(int, {('narrator', 'get'): 1, ('food', 'get'): 1}),
#  '85': defaultdict(int, {('reader', 'get'): 1}),
#  '86': defaultdict(int,
#              {('friend', 'relapse'): 1,
#               ('friend', 'be'): 2,
#               ('SO_neutral', 'get'): 1,
#               ('SO_any', 'get'): 1,
#               ('friend', 'share'): 2,
#               ('friend', 'faint'): 1,
#               ('friend', 'feel'): 1,
#               ('friend', 'have'): 1,
#               ('friend', 'want'): 2,
#               ('friend', 'disregard'): 1,
#               ('friend', 'know'): 1,
#               ('friend', 'tell'): 1}),
#  '87': defaultdict(int,
#              {('narrator', 'question'): 1,
#               ('family', 'come'): 1,
#               ('family', 'act'): 1,
#               ('family', 'need'): 1,
#               ('family', 'do'): 1,
#               ('family', 'angry'): 1}),
#  '88': defaultdict(int,
#              {('SO_female', 'save'): 1,
#               ('SO_any', 'save'): 1,
#               ('friend', 'save'): 1,
#               ('SO_female', 'want'): 2,
#               ('SO_any', 'want'): 2,
#               ('friend', 'want'): 2,
#               ('SO_female', 'go'): 1,
#               ('SO_any', 'go'): 1,
#               ('friend', 'go'): 1,
#               ('SO_female', 'say'): 1,
#               ('SO_any', 'say'): 1,
#               ('friend', 'say'): 1,
#               ('SO_female', 'sleepin'): 1,
#               ('SO_any', 'sleepin'): 1,
#               ('friend', 'sleepin'): 1,
#               ('SO_female', 'trust'): 1,
#               ('SO_any', 'trust'): 1,
#               ('friend', 'trust'): 1}),
#  '89': defaultdict(int, {('narrator', 'sick'): 1}),
#  '90': defaultdict(int,
#              {('family', 'get'): 1,
#               ('family', 'make'): 1,
#               ('ex_SO', 'stray'): 1,
#               ('family', 'point'): 1,
#               ('reader', 'hurt'): 1,
#               ('family', 'be'): 1,
#               ('family', 'struggle'): 1}),
#  '91': defaultdict(int, {('narrator', 'give'): 1}),
#  '92': defaultdict(int,
#              {('friend', '’s'): 1,
#               ('friend', 'tend'): 1,
#               ('friend', 'talk'): 1,
#               ('friend', 'mean'): 1,
#               ('friend', 'have'): 2,
#               ('friend', 'react'): 1,
#               ('friend', 'get'): 2,
#               ('friend', 'be'): 1,
#               ('friend', 'love'): 1,
#               ('narrator', 'uncomfortable'): 1,
#               ('narrator', 'feel'): 1,
#               ('friend', 'include'): 1,
#               ('friend', 'make'): 1}),
#  '93': defaultdict(int,
#              {('family', 'live'): 1,
#               ('narrator', 'happen'): 1,
#               ('narrator', 'be'): 1,
#               ('friend', 'do'): 1,
#               ('narrator', 'have'): 1,
#               ('friend', 'turn'): 1,
#               ('narrator', 'know'): 1,
#               ('narrator', 'find'): 1}),
#  '94': defaultdict(int,
#              {('family', 'put'): 1,
#               ('family', 'watch'): 1,
#               ('narrator', 'eat'): 1,
#               ('family', 'do'): 2,
#               ('family', 'be'): 1,
#               ('narrator', 'see'): 1,
#               ('food', 'see'): 1}),
#  '95': defaultdict(int,
#              {('narrator', 'feel'): 1,
#               ('reader', 'need'): 1,
#               ('narrator', 'worse'): 1}),
#  '96': defaultdict(int,
#              {('friend', 'anorexia'): 1,
#               ('friend', 'give'): 1,
#               ('friend', 'hestitated'): 1,
#               ('friend', 'have'): 3,
#               ('friend', 'tell'): 1,
#               ('friend', 'post'): 1,
#               ('friend', 'get'): 1,
#               ('friend', 'be'): 1,
#               ('friend', 'find'): 1,
#               ('friend', 'start'): 1}),
#  '97': defaultdict(int,
#              {('reader', 'know'): 2,
#               ('doctor', 'be'): 1,
#               ('medical_prof', 'be'): 1,
#               ('narrator', 'know'): 1}),
#  '98': defaultdict(int, {('food', 'do'): 1, ('narrator', 'have'): 1}),
#  '99': defaultdict(int, {('narrator', 'notice'): 1, ('narrator', 'know'): 1}),
#  '100': defaultdict(int, {}),
#  '101': defaultdict(int, {}),
#  '102': defaultdict(int, {('narrator', 'help'): 1}),
#  '103': defaultdict(int,
#              {('therapist', 'know'): 1,
#               ('medical_prof', 'know'): 1,
#               ('ED', 'look'): 1,
#               ('therapist', 'tell'): 1,
#               ('medical_prof', 'tell'): 1,
#               ('therapist', 'be'): 1,
#               ('medical_prof', 'be'): 1,
#               ('therapist', 'reach'): 1,
#               ('medical_prof', 'reach'): 1,
#               ('reader', 'be'): 1,
#               ('SO_neutral', 'struggle'): 1,
#               ('SO_any', 'struggle'): 1,
#               ('ED', 'be'): 1,
#               ('reader', 'reach'): 1,
#               ('reader', 'do'): 1}),
#  '104': defaultdict(int, {('narrator', 'have'): 1}),
#  '105': defaultdict(int,
#              {('reader', 'read'): 1,
#               ('reader', 'be'): 1,
#               ('reader', 'help'): 1,
#               ('reader', 'meet'): 1,
#               ('reader', 'do'): 1}),
#  '106': defaultdict(int,
#              {('narrator', 'feel'): 1,
#               ('narrator', 'pain'): 1,
#               ('narrator', 'control'): 1}),
#  '107': defaultdict(int, {}),
#  '108': defaultdict(int,
#              {('doctor', 'have'): 1,
#               ('medical_prof', 'have'): 1,
#               ('family', 'die'): 1,
#               ('reader', 'name'): 1,
#               ('therapist', 'be'): 1,
#               ('medical_prof', 'be'): 1}),
#  '109': defaultdict(int, {('narrator', 'want'): 2, ('narrator', 'be'): 1}),
#  '110': defaultdict(int, {('narrator', 'make'): 1, ('reader', 'think'): 1}),
#  '111': defaultdict(int, {}),
#  '112': defaultdict(int,
#              {('food', 'have'): 1,
#               ('narrator', 'be'): 1,
#               ('family', 'seem'): 1,
#               ('family', 'struggle'): 1}),
#  '113': defaultdict(int, {}),
#  '114': defaultdict(int,
#              {('family', 'wake'): 1,
#               ('narrator', 'be'): 1,
#               ('reader', 'resist'): 1,
#               ('reader', 'wanna'): 1,
#               ('reader', '’re'): 1,
#               ('friend', 'be'): 1,
#               ('reader', 'have'): 1,
#               ('family', 'call'): 1,
#               ('reader', 'know'): 1,
#               ('friend', 'monitor'): 1,
#               ('narrator', 'have'): 1,
#               ('narrator', 'let'): 1,
#               ('narrator', 'help'): 1}),
#  '115': defaultdict(int,
#              {('reader', 'should'): 1,
#               ('friend', 'say'): 1,
#               ('friend', 'have'): 1,
#               ('friend', 'get'): 1,
#               ('ED', 'be'): 1,
#               ('narrator', 'want'): 1}),
#  '116': defaultdict(int, {}),
#  '117': defaultdict(int, {('narrator', 'be'): 1, ('narrator', 'easier'): 1}),
#  '118': defaultdict(int,
#              {('ED', 'have'): 1,
#               ('narrator', 'get'): 1,
#               ('doctor', 'go'): 1,
#               ('medical_prof', 'go'): 1,
#               ('reader', 'tell'): 1}),
#  '119': defaultdict(int,
#              {('SO_male', 'have'): 2,
#               ('SO_any', 'have'): 2,
#               ('SO_male', 'focus'): 1,
#               ('SO_any', 'focus'): 1,
#               ('SO_male', 'see'): 1,
#               ('SO_any', 'see'): 1,
#               ('SO_male', 'say'): 2,
#               ('SO_any', 'say'): 2,
#               ('SO_male', 'be'): 1,
#               ('SO_any', 'be'): 1,
#               ('SO_male', 'talk'): 1,
#               ('SO_any', 'talk'): 1,
#               ('narrator', 'feel'): 1,
#               ('SO_male', 'dismiss'): 1,
#               ('SO_any', 'dismiss'): 1,
#               ('SO_male', 'understand'): 1,
#               ('SO_any', 'understand'): 1}),
#  '120': defaultdict(int,
#              {('friend', 'help'): 1,
#               ('friend', 'make'): 1,
#               ('narrator', 'be'): 1,
#               ('narrator', 'want'): 1}),
#  '121': defaultdict(int,
#              {('narrator', 'nauseous'): 2,
#               ('food', 'taste'): 1,
#               ('ex_SO', 'make'): 1,
#               ('ex_SO', 'get'): 1}),
#  '122': defaultdict(int,
#              {('family', 'starve'): 1, ('friend', 'romanticise'): 1}),
#  '123': defaultdict(int, {}),
#  '124': defaultdict(int,
#              {('therapist', 'suggest'): 1,
#               ('medical_prof', 'suggest'): 1,
#               ('reader', 'feel'): 1}),
#  '125': defaultdict(int, {('narrator', 'do'): 1, ('narrator', 'narrow'): 1}),
#  '126': defaultdict(int, {}),
#  '127': defaultdict(int,
#              {('SO_neutral', 'deal'): 1,
#               ('SO_any', 'deal'): 1,
#               ('SO_neutral', 'lie'): 1,
#               ('SO_any', 'lie'): 1,
#               ('SO_neutral', '’s'): 2,
#               ('SO_any', '’s'): 2,
#               ('SO_neutral', 'talk'): 1,
#               ('SO_any', 'talk'): 1,
#               ('SO_neutral', 'go'): 1,
#               ('SO_any', 'go'): 1,
#               ('SO_neutral', 'hat'): 1,
#               ('SO_any', 'hat'): 1,
#               ('SO_neutral', 'look'): 1,
#               ('SO_any', 'look'): 1,
#               ('SO_neutral', 'respond'): 1,
#               ('SO_any', 'respond'): 1,
#               ('SO_neutral', 'be'): 2,
#               ('SO_any', 'be'): 2,
#               ('SO_neutral', 'need'): 1,
#               ('SO_any', 'need'): 1,
#               ('SO_neutral', 'make'): 1,
#               ('SO_any', 'make'): 1}),
#  '128': defaultdict(int, {('reader', 'journey'): 1}),
#  '129': defaultdict(int,
#              {('friend', 'have'): 1,
#               ('friend', 'think'): 1,
#               ('friend', "'s"): 1,
#               ('friend', 'be'): 2,
#               ('ex_SO', 'have'): 1,
#               ('friend', 'want'): 1,
#               ('reader', 'force'): 1,
#               ('friend', 'kill'): 1,
#               ('friend', 'throw'): 1,
#               ('friend', 'clean'): 1,
#               ('friend', 'say'): 1}),
#  '130': defaultdict(int, {}),
#  '131': defaultdict(int, {}),
#  '132': defaultdict(int, {}),
#  '133': defaultdict(int, {('ED', 'affect'): 1}),
#  '134': defaultdict(int,
#              {('reader', 'be'): 1,
#               ('reader', 'go'): 1,
#               ('family', 'be'): 1,
#               ('family', 'have'): 1,
#               ('family', 'put'): 1,
#               ('family', 'eat'): 1}),
#  '135': defaultdict(int, {('narrator', 'weight'): 1}),
#  '136': defaultdict(int,
#              {('narrator', 'forget'): 1, ('narrator', 'hungry'): 1}),
#  '137': defaultdict(int,
#              {('reader', 'eat'): 1,
#               ('reader', 'be'): 1,
#               ('narrator', 'eat'): 1,
#               ('reader', 'want'): 1,
#               ('reader', 'come'): 1,
#               ('reader', 'express'): 1}),
#  '138': defaultdict(int, {}),
#  '139': defaultdict(int, {}),
#  '140': defaultdict(int, {}),
#  '141': defaultdict(int, {}),
#  '142': defaultdict(int, {('narrator', 'recover'): 1}),
#  '143': defaultdict(int, {}),
#  '144': defaultdict(int,
#              {('narrator', 'be'): 1,
#               ('narrator', 'start'): 1,
#               ('family', 'start'): 1,
#               ('family', 'ask'): 1,
#               ('narrator', 'protein'): 1}),
#  '145': defaultdict(int,
#              {('SO_female', 'open'): 1,
#               ('SO_any', 'open'): 1,
#               ('friend', 'open'): 1,
#               ('SO_female', 'say'): 1,
#               ('SO_any', 'say'): 1,
#               ('friend', 'say'): 1,
#               ('SO_female', 'tell'): 1,
#               ('SO_any', 'tell'): 1,
#               ('friend', 'tell'): 1,
#               ('SO_female', 'go'): 1,
#               ('SO_any', 'go'): 1,
#               ('friend', 'go'): 1,
#               ('SO_female', 'beat'): 1,
#               ('SO_any', 'beat'): 1,
#               ('friend', 'beat'): 1}),
#  '146': defaultdict(int, {}),
#  '147': defaultdict(int,
#              {('family', 'send'): 1,
#               ('doctor', 'send'): 1,
#               ('medical_prof', 'send'): 1,
#               ('family', 'say'): 1,
#               ('doctor', 'say'): 1,
#               ('medical_prof', 'say'): 1,
#               ('family', 'explain'): 1,
#               ('doctor', 'explain'): 1,
#               ('medical_prof', 'explain'): 1,
#               ('reader', 'work'): 1}),
#  '148': defaultdict(int,
#              {('family', 'suffer'): 1,
#               ('family', 'eat'): 1,
#               ('reader', 'get'): 1,
#               ('reader', 'be'): 1}),
#  '149': defaultdict(int,
#              {('narrator', 'want'): 1, ('medical_prof', 'have'): 1}),
#  '150': defaultdict(int, {('narrator', 'tell'): 1, ('narrator', 'get'): 1}),
#  '151': defaultdict(int, {}),
#  '152': defaultdict(int,
#              {('therapist', 'get'): 1,
#               ('medical_prof', 'get'): 1,
#               ('family', 'be'): 1}),
#  '153': defaultdict(int,
#              {('doctor', 'tell'): 1,
#               ('medical_prof', 'tell'): 1,
#               ('narrator', 'happy'): 1,
#               ('family', 'make'): 1,
#               ('narrator', 'eat'): 1}),
#  '154': defaultdict(int,
#              {('friend', 'develop'): 1,
#               ('friend', 'start'): 1,
#               ('friend', 'be'): 3,
#               ('friend', 'get'): 1,
#               ('friend', 'come'): 1,
#               ('friend', 'begin'): 1,
#               ('friend', '’s'): 1,
#               ('friend', 'eat'): 2,
#               ('friend', 'go'): 1,
#               ('friend', 'open'): 1,
#               ('friend', 'talk'): 1,
#               ('friend', 'say'): 1,
#               ('friend', 'refuse'): 1,
#               ('friend', 'tell'): 2,
#               ('friend', 'want'): 1}),
#  '155': defaultdict(int,
#              {('family', 'be'): 2,
#               ('family', 'lose'): 1,
#               ('family', 'become'): 1,
#               ('family', 'start'): 1,
#               ('narrator', 'be'): 1,
#               ('food', 'be'): 1,
#               ('family', 'tell'): 2,
#               ('family', 'struggle'): 1,
#               ('narrator', 'help'): 1,
#               ('family', 'help'): 1}),
#  '156': defaultdict(int, {}),
#  '157': defaultdict(int,
#              {('family', 'say'): 1,
#               ('family', 'promote'): 1,
#               ('family', 'tell'): 1,
#               ('family', 'be'): 1}),
#  '158': defaultdict(int,
#              {('narrator', 'have'): 1,
#               ('friend', 'have'): 1,
#               ('friend', 'operate'): 1,
#               ('narrator', 'miserable'): 1}),
#  '159': defaultdict(int,
#              {('narrator', 'fight'): 1,
#               ('food', 'be'): 1,
#               ('narrator', 'hopeful'): 1}),
#  '160': defaultdict(int,
#              {('SO_female', 'be'): 4,
#               ('SO_any', 'be'): 4,
#               ('friend', 'be'): 4,
#               ('SO_female', 'slim'): 1,
#               ('SO_any', 'slim'): 1,
#               ('friend', 'slim'): 1,
#               ('SO_female', 'associate'): 1,
#               ('SO_any', 'associate'): 1,
#               ('friend', 'associate'): 1,
#               ('SO_female', 'see'): 1,
#               ('SO_any', 'see'): 1,
#               ('friend', 'see'): 1,
#               ('SO_female', 'starve'): 1,
#               ('SO_any', 'starve'): 1,
#               ('friend', 'starve'): 1,
#               ('SO_female', 'have'): 2,
#               ('SO_any', 'have'): 2,
#               ('friend', 'have'): 2,
#               ('SO_female', 'think'): 1,
#               ('SO_any', 'think'): 1,
#               ('friend', 'think'): 1,
#               ('SO_female', 'work'): 1,
#               ('SO_any', 'work'): 1,
#               ('friend', 'work'): 1,
#               ('SO_female', 'accept'): 1,
#               ('SO_any', 'accept'): 1,
#               ('friend', 'accept'): 1,
#               ('narrator', 'correct'): 1,
#               ('SO_female', 'start'): 1,
#               ('SO_any', 'start'): 1,
#               ('friend', 'start'): 1,
#               ('SO_female', 'need'): 1,
#               ('SO_any', 'need'): 1,
#               ('friend', 'need'): 1}),
#  '161': defaultdict(int, {}),
#  '162': defaultdict(int,
#              {('narrator', 'ask'): 1,
#               ('nurse', 'ask'): 1,
#               ('medical_prof', 'ask'): 1,
#               ('narrator', 'be'): 1,
#               ('nurse', 'be'): 1,
#               ('medical_prof', 'be'): 1}),
#  '163': defaultdict(int,
#              {('ED', 'become'): 1,
#               ('reader', 'do'): 1,
#               ('narrator', 'make'): 1,
#               ('narrator', 'mess'): 1,
#               ('ex_SO', 'be'): 1}),
#  '164': defaultdict(int, {('narrator', 'be'): 1}),
#  '165': defaultdict(int, {('food', 'be'): 1, ('food', 'seem'): 1}),
#  '166': defaultdict(int,
#              {('doctor', 'be'): 1,
#               ('medical_prof', 'be'): 1,
#               ('family', 'make'): 1,
#               ('SO_male', 'project'): 1,
#               ('SO_any', 'project'): 1,
#               ('family', 'project'): 1,
#               ('reader', 'be'): 2,
#               ('narrator', 'go'): 1,
#               ('doctor', 'agree'): 1,
#               ('medical_prof', 'agree'): 1,
#               ('therapist', 'say'): 1,
#               ('medical_prof', 'say'): 1,
#               ('therapist', 'specialize'): 1,
#               ('medical_prof', 'specialize'): 1,
#               ('therapist', 'want'): 1,
#               ('medical_prof', 'want'): 1,
#               ('narrator', 'find'): 1}),
#  '167': defaultdict(int,
#              {('reader', 'have'): 1,
#               ('food', 'be'): 1,
#               ('food', 'touch'): 1,
#               ('narrator', 'depress'): 1,
#               ('food', 'help'): 1,
#               ('narrator', 'be'): 1}),
#  '168': defaultdict(int, {('reader', 'have'): 1}),
#  '169': defaultdict(int,
#              {('narrator', 'feel'): 4,
#               ('narrator', 'improve'): 1,
#               ('narrator', 'get'): 1,
#               ('family', 'begin'): 1,
#               ('family', 'be'): 2,
#               ('family', '’s'): 2,
#               ('family', 'do'): 1,
#               ('narrator', 'be'): 1,
#               ('narrator', 'better'): 1,
#               ('reader', 'offer'): 1}),
#  '170': defaultdict(int,
#              {('narrator', 'nauseous'): 1,
#               ('food', 'be'): 1,
#               ('reader', 'be'): 1,
#               ('reader', 'eat'): 1}),
#  '171': defaultdict(int,
#              {('narrator', 'begin'): 1,
#               ('narrator', 'gain'): 1,
#               ('family', 'have'): 2,
#               ('family', 'be'): 1,
#               ('reader', 'have'): 1,
#               ('food', 'be'): 1,
#               ('family', 'jump'): 1,
#               ('family', 'say'): 1,
#               ('family', 'tell'): 1}),
#  '172': defaultdict(int,
#              {('friend', 'say'): 1,
#               ('family', 'say'): 1,
#               ('family', 'care'): 1}),
#  '173': defaultdict(int,
#              {('reader', 'name'): 1,
#               ('family', 'realize'): 1,
#               ('doctor', 'be'): 1,
#               ('medical_prof', 'be'): 1,
#               ('food', 'cause'): 1,
#               ('family', 'be'): 1,
#               ('family', 'say'): 1,
#               ('reader', 'think'): 1}),
#  '174': defaultdict(int,
#              {('SO_neutral', 'relapse'): 1,
#               ('SO_any', 'relapse'): 1,
#               ('SO_neutral', 'find'): 1,
#               ('SO_any', 'find'): 1,
#               ('SO_neutral', 'keep'): 1,
#               ('SO_any', 'keep'): 1,
#               ('SO_neutral', 'look'): 2,
#               ('SO_any', 'look'): 2,
#               ('narrator', 'be'): 1}),
#  '175': defaultdict(int, {('food', 'eat'): 1, ('narrator', 'stop'): 1}),
#  '176': defaultdict(int,
#              {('narrator', 'eat'): 1,
#               ('family', 'say'): 1,
#               ('family', 'make'): 1,
#               ('narrator', 'be'): 1,
#               ('narrator', 'argue'): 1,
#               ('ex_SO', 'be'): 1,
#               ('family', 'know'): 1,
#               ('reader', 'think'): 1,
#               ('reader', 'be'): 2,
#               ('reader', 'felt'): 1,
#               ('reader', 'take'): 1,
#               ('reader', 'listen'): 1,
#               ('reader', 'know'): 1,
#               ('reader', 'have'): 3,
#               ('reader', 'want'): 1,
#               ('reader', 'wait'): 1,
#               ('reader', 'control'): 1,
#               ('food', 'be'): 1}),
#  '177': defaultdict(int,
#              {('friend', 'tell'): 1,
#               ('narrator', '’re'): 1,
#               ('friend', 'be'): 2,
#               ('narrator', 'be'): 1,
#               ('narrator', 'think'): 1,
#               ('family', 'be'): 1}),
#  '178': defaultdict(int, {}),
#  '179': defaultdict(int,
#              {('SO_female', 'develop'): 1,
#               ('SO_any', 'develop'): 1,
#               ('friend', 'develop'): 1,
#               ('SO_female', 'muster'): 1,
#               ('SO_any', 'muster'): 1,
#               ('friend', 'muster'): 1,
#               ('SO_female', 'want'): 1,
#               ('SO_any', 'want'): 1,
#               ('friend', 'want'): 1,
#               ('SO_female', 'start'): 1,
#               ('SO_any', 'start'): 1,
#               ('friend', 'start'): 1,
#               ('SO_female', 'say'): 1,
#               ('SO_any', 'say'): 1,
#               ('friend', 'say'): 1,
#               ('SO_female', 'feel'): 2,
#               ('SO_any', 'feel'): 2,
#               ('friend', 'feel'): 2,
#               ('SO_female', 'felt'): 1,
#               ('SO_any', 'felt'): 1,
#               ('friend', 'felt'): 1,
#               ('SO_female', 'get'): 1,
#               ('SO_any', 'get'): 1,
#               ('friend', 'get'): 1,
#               ('SO_female', 'be'): 1,
#               ('SO_any', 'be'): 1,
#               ('friend', 'be'): 1}),
#  '180': defaultdict(int,
#              {('family', 'be'): 3,
#               ('family', 'eat'): 2,
#               ('family', 'want'): 1,
#               ('family', 'use'): 1}),
#  '181': defaultdict(int,
#              {('narrator', 'add'): 1,
#               ('food', 'add'): 1,
#               ('narrator', 'lack'): 1,
#               ('reader', 'know'): 1}),
#  '182': defaultdict(int,
#              {('doctor', 'see'): 1,
#               ('medical_prof', 'see'): 1,
#               ('narrator', 'have'): 1,
#               ('doctor', 'find'): 1,
#               ('medical_prof', 'find'): 1}),
#  '183': defaultdict(int,
#              {('doctor', 'tell'): 1,
#               ('medical_prof', 'tell'): 1,
#               ('family', 'make'): 1,
#               ('friend', 'see'): 1,
#               ('family', 'see'): 1,
#               ('friend', 'notice'): 1,
#               ('family', 'notice'): 1,
#               ('friend', 'bring'): 1,
#               ('family', 'bring'): 1,
#               ('reader', 'lose'): 1,
#               ('reader', 'be'): 1,
#               ('reader', 'look'): 1,
#               ('narrator', 'reflect'): 1}),
#  '184': defaultdict(int, {('reader', 'see'): 1, ('ex_SO', 'fix'): 1}),
#  '185': defaultdict(int,
#              {('narrator', 'uncomfortable'): 1, ('narrator', 'be'): 1}),
#  '186': defaultdict(int,
#              {('narrator', 'wrong'): 1,
#               ('food', 'wrong'): 1,
#               ('reader', 'give'): 1}),
#  '187': defaultdict(int, {}),
#  '188': defaultdict(int,
#              {('doctor', 'prescribe'): 1,
#               ('medical_prof', 'prescribe'): 1,
#               ('narrator', 'raise'): 1,
#               ('doctor', 'say'): 1,
#               ('medical_prof', 'say'): 1}),
#  '189': defaultdict(int,
#              {('narrator', 'go'): 1,
#               ('food', 'be'): 2,
#               ('narrator', 'eat'): 1}),
#  '190': defaultdict(int, {('friend', 'be'): 1}),
#  '191': defaultdict(int, {('reader', 'have'): 1}),
#  '192': defaultdict(int, {('friend', 'tell'): 2, ('friend', 'struggle'): 1}),
#  '193': defaultdict(int,
#              {('reader', 'see'): 1,
#               ('narrator', 'feel'): 1,
#               ('narrator', 'want'): 1,
#               ('reader', 'know'): 1}),
#  '194': defaultdict(int,
#              {('family', 'struggle'): 1,
#               ('ED', 'eat'): 1,
#               ('family', 'star'): 1,
#               ('narrator', 'uncomfortable'): 2,
#               ('family', 'deny'): 1,
#               ('family', 'do'): 1,
#               ('family', 'say'): 1,
#               ('narrator', 'be'): 1,
#               ('narrator', 'want'): 1}),
#  '195': defaultdict(int, {}),
#  '196': defaultdict(int,
#              {('SO_male', 'say'): 4,
#               ('SO_any', 'say'): 4,
#               ('SO_male', 'stop'): 1,
#               ('SO_any', 'stop'): 1,
#               ('SO_male', '’s'): 2,
#               ('SO_any', '’s'): 2,
#               ('SO_male', 'tell'): 1,
#               ('SO_any', 'tell'): 1,
#               ('SO_male', 'hat'): 1,
#               ('SO_any', 'hat'): 1,
#               ('SO_male', 'respond'): 1,
#               ('SO_any', 'respond'): 1,
#               ('reader', 'love'): 1,
#               ('SO_male', 'do'): 2,
#               ('SO_any', 'do'): 2,
#               ('SO_male', 'try'): 2,
#               ('SO_any', 'try'): 2,
#               ('SO_male', 'attractive'): 1,
#               ('SO_any', 'attractive'): 1,
#               ('SO_male', 'ignore'): 1,
#               ('SO_any', 'ignore'): 1,
#               ('SO_male', 'refuse'): 1,
#               ('SO_any', 'refuse'): 1,
#               ('therapist', 'be'): 1,
#               ('medical_prof', 'be'): 1,
#               ('SO_male', 'like'): 1,
#               ('SO_any', 'like'): 1,
#               ('SO_male', 'need'): 2,
#               ('SO_any', 'need'): 2,
#               ('SO_male', 'get'): 1,
#               ('SO_any', 'get'): 1,
#               ('reader', 'do'): 1,
#               ('SO_male', 'talk'): 1,
#               ('SO_any', 'talk'): 1,
#               ('SO_male', 'monitor'): 1,
#               ('SO_any', 'monitor'): 1,
#               ('SO_male', 'purge'): 1,
#               ('SO_any', 'purge'): 1,
#               ('SO_male', 'think'): 1,
#               ('SO_any', 'think'): 1,
#               ('SO_male', 'have'): 1,
#               ('SO_any', 'have'): 1,
#               ('SO_male', 'be'): 1,
#               ('SO_any', 'be'): 1}),
#  '197': defaultdict(int, {('reader', 'come'): 1}),
#  '198': defaultdict(int,
#              {('food', 'be'): 1,
#               ('food', 'make'): 1,
#               ('narrator', 'conscious'): 1,
#               ('narrator', 'feel'): 1}),
#  '199': defaultdict(int,
#              {('SO_female', 'struggle'): 1,
#               ('SO_any', 'struggle'): 1,
#               ('friend', 'struggle'): 1,
#               ('doctor', 'struggle'): 1,
#               ('medical_prof', 'struggle'): 1,
#               ('SO_female', 'get'): 1,
#               ('SO_any', 'get'): 1,
#               ('friend', 'get'): 1,
#               ('doctor', 'get'): 1,
#               ('medical_prof', 'get'): 1,
#               ('SO_female', 'choose'): 1,
#               ('SO_any', 'choose'): 1,
#               ('friend', 'choose'): 1,
#               ('doctor', 'choose'): 1,
#               ('medical_prof', 'choose'): 1,
#               ('SO_female', 'fast'): 1,
#               ('SO_any', 'fast'): 1,
#               ('friend', 'fast'): 1,
#               ('doctor', 'fast'): 1,
#               ('medical_prof', 'fast'): 1,
#               ('SO_female', 'can'): 1,
#               ('SO_any', 'can'): 1,
#               ('friend', 'can'): 1,
#               ('doctor', 'can'): 1,
#               ('medical_prof', 'can'): 1,
#               ('SO_female', 'be'): 1,
#               ('SO_any', 'be'): 1,
#               ('friend', 'be'): 1,
#               ('doctor', 'be'): 1,
#               ('medical_prof', 'be'): 1,
#               ('SO_female', 'intertwine'): 1,
#               ('SO_any', 'intertwine'): 1,
#               ('friend', 'intertwine'): 1,
#               ('doctor', 'intertwine'): 1,
#               ('medical_prof', 'intertwine'): 1,
#               ('SO_female', 'think'): 1,
#               ('SO_any', 'think'): 1,
#               ('friend', 'think'): 1,
#               ('doctor', 'think'): 1,
#               ('medical_prof', 'think'): 1,
#               ('SO_female', 'have'): 2,
#               ('SO_any', 'have'): 2,
#               ('friend', 'have'): 2,
#               ('doctor', 'have'): 2,
#               ('medical_prof', 'have'): 2,
#               ('family', 'care'): 1,
#               ('SO_female', 'find'): 1,
#               ('SO_any', 'find'): 1,
#               ('friend', 'find'): 1,
#               ('doctor', 'find'): 1,
#               ('medical_prof', 'find'): 1,
#               ('SO_female', 'want'): 1,
#               ('SO_any', 'want'): 1,
#               ('friend', 'want'): 1,
#               ('doctor', 'want'): 1,
#               ('medical_prof', 'want'): 1}),
#  '200': defaultdict(int,
#              {('SO_male', 'have'): 3,
#               ('SO_any', 'have'): 3,
#               ('friend', 'have'): 3,
#               ('SO_male', 'come'): 1,
#               ('SO_any', 'come'): 1,
#               ('friend', 'come'): 1,
#               ('SO_male', 'refer'): 1,
#               ('SO_any', 'refer'): 1,
#               ('friend', 'refer'): 1,
#               ('family', 'refer'): 1,
#               ('SO_male', 'be'): 1,
#               ('SO_any', 'be'): 1,
#               ('friend', 'be'): 1,
#               ('SO_male', 'say'): 2,
#               ('SO_any', 'say'): 2,
#               ('friend', 'say'): 2,
#               ('SO_male', 'eat'): 2,
#               ('SO_any', 'eat'): 2,
#               ('friend', 'eat'): 2,
#               ('family', 'feel'): 1}),
#  '201': defaultdict(int,
#              {('food', 'drop'): 1,
#               ('narrator', 'hungry'): 1,
#               ('narrator', 'wonder'): 1}),
#  '202': defaultdict(int,
#              {('ED', 'seem'): 1, ('ED', 'be'): 1, ('ED', 'tell'): 1}),
#  '203': defaultdict(int,
#              {('reader', 'acknowledge'): 1,
#               ('friend', 'mimic'): 1,
#               ('friend', 'eat'): 1,
#               ('friend', 'take'): 1,
#               ('narrator', 'take'): 1}),
#  '204': defaultdict(int, {('narrator', 'wrong'): 1, ('family', 'shut'): 1}),
#  '205': defaultdict(int,
#              {('family', 'worry'): 1,
#               ('family', 'call'): 1,
#               ('friend', 'give'): 1,
#               ('family', 'ask'): 1,
#               ('narrator', 'question'): 1,
#               ('narrator', 'go'): 1,
#               ('narrator', 'hit'): 1,
#               ('narrator', 'eat'): 1}),
#  '206': defaultdict(int, {('family', 'make'): 1}),
#  '207': defaultdict(int,
#              {('family', 'cook'): 2,
#               ('family', 'get'): 1,
#               ('narrator', 'buy'): 1}),
#  '208': defaultdict(int, {('narrator', 'feel'): 1}),
#  '209': defaultdict(int, {('family', '’s'): 1, ('narrator', 'depress'): 1}),
#  '210': defaultdict(int,
#              {('family', 'do'): 1,
#               ('narrator', 'pay'): 1,
#               ('narrator', 'feel'): 1,
#               ('narrator', 'make'): 1}),
#  '211': defaultdict(int, {('family', 'be'): 1}),
#  '212': defaultdict(int,
#              {('friend', 'know'): 2,
#               ('friend', 'be'): 2,
#               ('friend', 'need'): 1,
#               ('narrator', 'listen'): 1,
#               ('narrator', 'angry'): 1,
# ...
#              {('SO_male', 'keep'): 1,
#               ('SO_any', 'keep'): 1,
#               ('friend', 'keep'): 1,
#               ('reader', 'be'): 1,
#               ('reader', 'eat'): 1,
#               ('SO_male', 'say'): 2,
#               ('SO_any', 'say'): 2,
#               ('friend', 'say'): 2,
#               ('SO_male', 'go'): 1,
#               ('SO_any', 'go'): 1,
#               ('friend', 'go'): 1,
#               ('SO_male', 'insist'): 1,
#               ('SO_any', 'insist'): 1,
#               ('friend', 'insist'): 1,
#               ('SO_male', 'get'): 2,
#               ('SO_any', 'get'): 2,
#               ('friend', 'get'): 2,
#               ('SO_male', 'felt'): 1,
#               ('SO_any', 'felt'): 1,
#               ('friend', 'felt'): 1}),
#  '900': defaultdict(int, {('narrator', 'take'): 1, ('narrator', 'kick'): 1}),
#  '901': defaultdict(int, {('narrator', 'relapse'): 1}),
#  '902': defaultdict(int, {('reader', 'have'): 1}),
#  '903': defaultdict(int, {('narrator', 'come'): 1}),
#  '904': defaultdict(int,
#              {('doctor', 'think'): 1, ('medical_prof', 'think'): 1}),
#  '905': defaultdict(int, {('reader', 'think'): 1}),
#  '906': defaultdict(int,
#              {('SO_male', 'comment'): 1,
#               ('SO_any', 'comment'): 1,
#               ('friend', 'comment'): 1,
#               ('SO_male', 'tell'): 1,
#               ('SO_any', 'tell'): 1,
#               ('friend', 'tell'): 1,
#               ('narrator', 'feel'): 1}),
#  '907': defaultdict(int,
#              {('doctor', 'end'): 1,
#               ('medical_prof', 'end'): 1,
#               ('food', 'end'): 1,
#               ('reader', 'dare'): 1}),
#  '908': defaultdict(int, {}),
#  '909': defaultdict(int,
#              {('SO_male', 'comment'): 2,
#               ('SO_any', 'comment'): 2,
#               ('friend', 'comment'): 2,
#               ('SO_male', 'say'): 2,
#               ('SO_any', 'say'): 2,
#               ('friend', 'say'): 2,
#               ('reader', "'re"): 1,
#               ('narrator', 'nervous'): 1,
#               ('SO_male', 'catch'): 1,
#               ('SO_any', 'catch'): 1,
#               ('friend', 'catch'): 1,
#               ('narrator', 'eat'): 1}),
#  '910': defaultdict(int,
#              {('family', 'consider'): 1,
#               ('reader', 'relate'): 1,
#               ('reader', 'think'): 2}),
#  '911': defaultdict(int,
#              {('narrator', 'suck'): 1,
#               ('family', 'suck'): 1,
#               ('food', 'suck'): 1,
#               ('reader', 'look'): 1,
#               ('ex_SO', 'be'): 1}),
#  '912': defaultdict(int,
#              {('reader', 'have'): 1,
#               ('reader', 'eat'): 1,
#               ('reader', 'need'): 2,
#               ('reader', "'re"): 2,
#               ('narrator', 'feel'): 1,
#               ('narrator', 'enter'): 1,
#               ('narrator', 'notice'): 1,
#               ('SO_male', 'tell'): 1,
#               ('SO_any', 'tell'): 1,
#               ('friend', 'tell'): 1,
#               ('family', 'say'): 1}),
#  '913': defaultdict(int,
#              {('friend', 'organise'): 1,
#               ('friend', 'work'): 1,
#               ('friend', 'overload'): 1}),
#  '914': defaultdict(int, {}),
#  '915': defaultdict(int,
#              {('SO_male', 'watch'): 1,
#               ('SO_any', 'watch'): 1,
#               ('friend', 'watch'): 1}),
#  '916': defaultdict(int, {('narrator', 'be'): 1, ('reader', 'find'): 1}),
#  '917': defaultdict(int,
#              {('reader', 'have'): 1,
#               ('friend', 'think'): 1,
#               ('narrator', 'love'): 1}),
#  '918': defaultdict(int,
#              {('reader', "'re"): 2,
#               ('reader', 'eat'): 1,
#               ('reader', 'purge/'): 1,
#               ('food', 'roll'): 1,
#               ('narrator', 'happen'): 1}),
#  '919': defaultdict(int, {}),
#  '920': defaultdict(int, {}),
#  '921': defaultdict(int,
#              {('family', 'be'): 1,
#               ('family', 'call'): 1,
#               ('reader', 'read'): 1}),
#  '922': defaultdict(int,
#              {('family', 'be'): 1,
#               ('friend', 'irl'): 1,
#               ('food', 'realise'): 1}),
#  '923': defaultdict(int,
#              {('family', 'comment'): 2,
#               ('family', 'eat'): 4,
#               ('family', 'say'): 2,
#               ('family', 'gain'): 1,
#               ('family', 'be'): 2,
#               ('family', 'trust'): 1,
#               ('family', 'start'): 1,
#               ('family', 'know'): 1,
#               ('family', 'have'): 1,
#               ('family', 'snap'): 1,
#               ('family', 'take'): 2,
#               ('reader', 'be'): 1,
#               ('family', 'support'): 1,
#               ('family', 'highlight'): 1,
#               ('family', "'s"): 1,
#               ('family', 'enable'): 1,
#               ('narrator', 'be'): 1,
#               ('narrator', 'hear'): 1,
#               ('family', 'call'): 1,
#               ('narrator', 'dwindle'): 1,
#               ('family', 'dwindle'): 1}),
#  '924': defaultdict(int,
#              {('narrator', 'feel'): 2,
#               ('family', 'scar'): 1,
#               ('narrator', 'want'): 2,
#               ('narrator', 'become'): 1,
#               ('narrator', 'give'): 1,
#               ('reader', 'get'): 1}),
#  '925': defaultdict(int,
#              {('SO_female', 'have'): 1,
#               ('SO_any', 'have'): 1,
#               ('friend', 'have'): 1,
#               ('SO_female', 'try'): 1,
#               ('SO_any', 'try'): 1,
#               ('friend', 'try'): 1,
#               ('SO_female', 'respond'): 2,
#               ('SO_any', 'respond'): 2,
#               ('friend', 'respond'): 2,
#               ('SO_female', 'eat'): 1,
#               ('SO_any', 'eat'): 1,
#               ('friend', 'eat'): 1}),
#  '926': defaultdict(int, {}),
#  '927': defaultdict(int, {('narrator', 'look'): 1}),
#  '928': defaultdict(int,
#              {('family', 'be'): 1,
#               ('narrator', 'be'): 1,
#               ('reader', 'give'): 1}),
#  '929': defaultdict(int,
#              {('narrator', 'do'): 1,
#               ('ED', 'be'): 1,
#               ('narrator', 'talk'): 1}),
#  '930': defaultdict(int, {}),
#  '931': defaultdict(int, {('food', 'do'): 1}),
#  '932': defaultdict(int,
#              {('narrator', 'sick'): 1,
#               ('reader', 'plan'): 1,
#               ('reader', 'know'): 1,
#               ('reader', 'have'): 1}),
#  '933': defaultdict(int, {('narrator', 'eat'): 1}),
#  '934': defaultdict(int, {('narrator', 'make'): 1, ('narrator', 'want'): 1}),
#  '935': defaultdict(int,
#              {('friend', 'be'): 1,
#               ('friend', 'read'): 1,
#               ('friend', 'manage'): 1,
#               ('friend', 'have'): 1,
#               ('friend', 'ask'): 1,
#               ('friend', 'think'): 2,
#               ('friend', 'eat'): 1,
#               ('friend', 'log'): 1,
#               ('friend', 'feel'): 1,
#               ('friend', 'talk'): 1}),
#  '936': defaultdict(int,
#              {('family', 'take'): 1,
#               ('ex_SO', 'be'): 1,
#               ('family', 'eat'): 1}),
#  '937': defaultdict(int, {('doctor', 'do'): 1, ('medical_prof', 'do'): 1}),
#  '938': defaultdict(int,
#              {('family', 'make'): 1,
#               ('reader', 'go'): 1,
#               ('reader', 'start'): 2,
#               ('reader', 'eat'): 1,
#               ('family', 'tell'): 2,
#               ('family', 'order'): 1,
#               ('family', 'insist'): 1,
#               ('family', 'knock'): 1}),
#  '939': defaultdict(int, {}),
#  '940': defaultdict(int,
#              {('narrator', 'be'): 2,
#               ('food', 'analyze'): 1,
#               ('reader', 'think'): 1,
#               ('food', 'be'): 1,
#               ('food', 'respond'): 1}),
#  '941': defaultdict(int, {('ED', 'be'): 1}),
#  '942': defaultdict(int,
#              {('friend', 'make'): 1,
#               ('doctor', 'be'): 1,
#               ('medical_prof', 'be'): 1,
#               ('friend', 'judge'): 1}),
#  '943': defaultdict(int, {('friend', 'know'): 1, ('friend', 'be'): 1}),
#  '944': defaultdict(int,
#              {('food', 'make'): 1,
#               ('SO_male', 'push'): 1,
#               ('SO_any', 'push'): 1,
#               ('friend', 'seem'): 1,
#               ('food', 'be'): 1,
#               ('ex_SO', 'drink'): 1,
#               ('friend', 'eat'): 1,
#               ('friend', 'feel'): 1}),
#  '945': defaultdict(int, {('reader', 'call'): 1, ('narrator', 'form'): 1}),
#  '946': defaultdict(int, {('narrator', 'throw'): 1, ('family', 'praise'): 1}),
#  '947': defaultdict(int,
#              {('family', 'complain'): 1,
#               ('family', "'s"): 1,
#               ('food', 'give'): 1}),
#  '948': defaultdict(int,
#              {('narrator', 'lose'): 1,
#               ('SO_male', 'tell'): 1,
#               ('SO_any', 'tell'): 1}),
#  '949': defaultdict(int,
#              {('narrator', 'feel'): 1,
#               ('ED', 'get'): 1,
#               ('narrator', 'get'): 1}),
#  '950': defaultdict(int,
#              {('family', 'be'): 1,
#               ('narrator', 'eat'): 1,
#               ('family', 'tell'): 1,
#               ('family', 'think'): 1}),
#  '951': defaultdict(int,
#              {('narrator', 'seem'): 1,
#               ('narrator', 'mess'): 1,
#               ('narrator', 'feel'): 1}),
#  '952': defaultdict(int, {('ex_SO', 'relapse'): 1, ('ED', 'relapse'): 1}),
#  '953': defaultdict(int, {('narrator', 'be'): 1, ('reader', 'give'): 1}),
#  '954': defaultdict(int,
#              {('doctor', 'say'): 2,
#               ('medical_prof', 'say'): 2,
#               ('reader', 'do'): 1}),
#  '955': defaultdict(int,
#              {('friend', 'try'): 1,
#               ('friend', 'say'): 1,
#               ('friend', 'go'): 1,
#               ('nurse', 'do'): 1,
#               ('medical_prof', 'do'): 1}),
#  '956': defaultdict(int,
#              {('SO_female', 'drink'): 1,
#               ('SO_any', 'drink'): 1,
#               ('SO_female', 'eat'): 2,
#               ('SO_any', 'eat'): 2,
#               ('SO_female', 'have'): 2,
#               ('SO_any', 'have'): 2}),
#  '957': defaultdict(int, {('narrator', 'happy'): 1, ('reader', 'stop'): 1}),
#  '958': defaultdict(int, {}),
#  '959': defaultdict(int, {('narrator', 'complications'): 1}),
#  '960': defaultdict(int,
#              {('family', 'seem'): 3,
#               ('family', 'say'): 1,
#               ('family', 'feel'): 1,
#               ('family', 'have'): 1,
#               ('family', 'tell'): 2,
#               ('reader', 'realllyyyy'): 1,
#               ('reader', 'be'): 1,
#               ('reader', 'want'): 1,
#               ('narrator', 'eat'): 1,
#               ('family', '’s'): 1,
#               ('reader', 'eat'): 2,
#               ('reader', 'go'): 1,
#               ('narrator', 'self'): 1,
#               ('family', 'keep'): 1,
#               ('reader', 'weight'): 1,
#               ('reader', 'weigh'): 1,
#               ('narrator', 'need'): 1,
#               ('narrator', 'lose'): 1,
#               ('family', 'shrug'): 1,
#               ('family', 'point'): 1}),
#  '961': defaultdict(int, {('food', 'get'): 1, ('friend', 'tell'): 1}),
#  '962': defaultdict(int,
#              {('SO_male', 'quit'): 1,
#               ('SO_any', 'quit'): 1,
#               ('SO_male', 'have'): 1,
#               ('SO_any', 'have'): 1,
#               ('SO_male', 'eat'): 1,
#               ('SO_any', 'eat'): 1,
#               ('SO_male', 'use'): 1,
#               ('SO_any', 'use'): 1,
#               ('SO_male', 'go'): 1,
#               ('SO_any', 'go'): 1,
#               ('narrator', '’s'): 1,
#               ('food', '’s'): 1,
#               ('SO_male', 'sit'): 1,
#               ('SO_any', 'sit'): 1}),
#  '963': defaultdict(int, {('family', 'cook'): 1, ('narrator', 'thin'): 1}),
#  '964': defaultdict(int,
#              {('narrator', 'know'): 1,
#               ('friend', 'ask'): 1,
#               ('narrator', 'help'): 1}),
#  '965': defaultdict(int, {('family', 'come'): 1, ('family', 'consider'): 1}),
#  '966': defaultdict(int, {('friend', 'care'): 1, ('friend', 'realize'): 1}),
#  '967': defaultdict(int, {}),
#  '968': defaultdict(int,
#              {('narrator', 'trigger'): 1, ('narrator', 'look'): 1}),
#  '969': defaultdict(int,
#              {('family', 'point'): 1,
#               ('ex_SO', 'have'): 1,
#               ('narrator', 'disgust'): 2,
#               ('family', 'keep'): 1,
#               ('family', 'do'): 1}),
#  '970': defaultdict(int,
#              {('therapist', 'pick'): 1, ('medical_prof', 'pick'): 1}),
#  '971': defaultdict(int, {('narrator', 'be'): 1}),
#  '972': defaultdict(int, {}),
#  '973': defaultdict(int,
#              {('doctor', 'be'): 1,
#               ('medical_prof', 'be'): 1,
#               ('doctor', 'think'): 1,
#               ('medical_prof', 'think'): 1,
#               ('doctor', 'threaten'): 1,
#               ('medical_prof', 'threaten'): 1,
#               ('doctor', 'right'): 1,
#               ('medical_prof', 'right'): 1,
#               ('friend', 'ignore'): 1}),
#  '974': defaultdict(int, {}),
#  '975': defaultdict(int,
#              {('SO_male', 'see'): 1,
#               ('SO_any', 'see'): 1,
#               ('friend', 'see'): 1,
#               ('narrator', 'feel'): 1,
#               ('family', 'comment'): 1}),
#  '976': defaultdict(int,
#              {('narrator', 'rise'): 1,
#               ('narrator', 'make'): 1,
#               ('reader', 'think'): 1}),
#  '977': defaultdict(int, {}),
#  '978': defaultdict(int, {}),
#  '979': defaultdict(int,
#              {('doctor', 'consider'): 1,
#               ('medical_prof', 'consider'): 1,
#               ('narrator', 'overweight'): 1,
#               ('doctor', 'say'): 2,
#               ('medical_prof', 'say'): 2,
#               ('narrator', 'go'): 1,
#               ('family', 'cook'): 1,
#               ('doctor', 'be'): 1,
#               ('medical_prof', 'be'): 1,
#               ('family', 'be'): 1}),
#  '980': defaultdict(int, {('narrator', 'last'): 1}),
#  '981': defaultdict(int,
#              {('narrator', 'change'): 1,
#               ('family', 'do'): 1,
#               ('ex_SO', 'fit'): 1,
#               ('reader', 'think'): 1}),
#  '982': defaultdict(int,
#              {('SO_neutral', 'tell'): 1,
#               ('SO_any', 'tell'): 1,
#               ('narrator', 'scar'): 1,
#               ('SO_neutral', 'express'): 1,
#               ('SO_any', 'express'): 1,
#               ('family', 'praise'): 1}),
#  '983': defaultdict(int, {('narrator', 'feel'): 1, ('food', 'feel'): 1}),
#  '984': defaultdict(int, {}),
#  '985': defaultdict(int, {}),
#  '986': defaultdict(int,
#              {('reader', 'know'): 1,
#               ('friend', 'make'): 1,
#               ('friend', 'keep'): 1,
#               ('friend', 'use'): 1,
#               ('friend', '’s'): 1,
#               ('friend', 'support'): 1,
#               ('narrator', 'go'): 1}),
#  '987': defaultdict(int, {('narrator', 'happen'): 1}),
#  '988': defaultdict(int, {('food', 'bring'): 1}),
#  '989': defaultdict(int,
#              {('family', 'count'): 1,
#               ('family', 'nag'): 1,
#               ('narrator', 'incentivized'): 1,
#               ('narrator', 'be'): 1,
#               ('family', 'keep'): 1,
#               ('family', 'eat'): 1,
#               ('family', 'have'): 2,
#               ('family', 'say'): 1,
#               ('family', 'do'): 1,
#               ('family', 'write'): 1,
#               ('family', 'restrict'): 1,
#               ('narrator', 'know'): 1,
#               ('narrator', 'track'): 1,
#               ('family', 'think'): 1,
#               ('family', 'stop'): 1,
#               ('narrator', 'tell'): 1}),
#  '990': defaultdict(int, {('narrator', 'eat'): 1, ('narrator', 'portion'): 1}),
#  '991': defaultdict(int, {('friend', 'be'): 1, ('food', 'do'): 1}),
#  '992': defaultdict(int, {('narrator', 'tell'): 1, ('reader', 'read'): 1}),
#  '993': defaultdict(int, {('family', 'care'): 1}),
#  '994': defaultdict(int,
#              {('narrator', 'say'): 1,
#               ('narrator', 'look'): 1,
#               ('narrator', 'expect'): 1,
#               ('narrator', 'experience'): 1,
#               ('reader', 'get'): 1}),
#  '995': defaultdict(int,
#              {('narrator', 'make'): 1,
#               ('narrator', 'feel'): 1,
#               ('family', 'happy'): 1,
#               ('family', 'know'): 1}),
#  '996': defaultdict(int, {}),
#  '997': defaultdict(int, {}),
#  '998': defaultdict(int, {('family', 'eat'): 2, ('family', 'refuse'): 1}),
#  '999': defaultdict(int, {('narrator', 'eat'): 1, ('friend', 'tell'): 1}),
#  ...}

# %%
verb_count_dict = pf.evaluate_verb_coverage(id_nsubj_verb_count_dict)

for _verb, _count in sorted(verb_count_dict.items(), key=lambda x: x[1], reverse=True)[:20]:
    print(_count, '\t', _verb) # + ' (' + str(_count) + ')')
# Out:
# 3581 	 be
# 1224 	 have
# 1055 	 feel
# 1014 	 say
# 813 	 eat
# 785 	 get
# 780 	 know
# 775 	 want
# 763 	 tell
# 683 	 go
# 673 	 do
# 599 	 make
# 541 	 think
# 327 	 start
# 321 	 see
# 294 	 look
# 279 	 come
# 275 	 try
# 268 	 ’s
# 255 	 take

# %% [markdown]
# Find verbs missing from lexicon

# %%
missing_verbs = set()
all_verbs = set()

for _id in id_nsubj_verb_count_dict.keys():
    for nsubj, _verb in id_nsubj_verb_count_dict[_id].keys():
        if _verb not in verb_power_dict.keys():
            missing_verbs.add(_verb)
        all_verbs.add(_verb)

for _id in id_dobj_verb_count_dict.keys():
    for dobj, _verb in id_dobj_verb_count_dict[_id].keys():
        if _verb not in verb_power_dict.keys():
            missing_verbs.add(_verb)
        all_verbs.add(_verb)

# %%
len(all_verbs)
# Out:
# 2141

# %%
len(missing_verbs)
# Out:
# 1073

# %%
79/309
# Out:
# 0.255663430420712

# %%
missing_verbs
# Out:
# {'sleepin',
#  'happy',
#  'harbor',
#  'homeschool',
#  '……',
#  'diet',
#  'transition',
#  'input',
#  'snack',
#  'leading',
#  'fatten',
#  'is',
#  'fluffy',
#  'gift',
#  'year',
#  'hard',
#  'gaslighitng',
#  'crummy',
#  'clue',
#  'slamming',
#  'excercises',
#  'flaw',
#  'dang',
#  'coddle',
#  'me',
#  'trivialize',
#  'butt',
#  'got',
#  'forcefeed',
#  'salad',
#  'disrespect',
#  'alternate',
#  'cripple',
#  'havr',
#  'approaching',
#  'callled',
#  'attenting',
#  'receiving',
#  'malnourish',
#  'miserable',
#  'wisks',
#  'realllyyyy',
#  'myeating',
#  'commend',
#  'deduce',
#  'are',
#  'incase',
#  'crave',
#  'funny',
#  'derail',
#  'brag',
#  'tick',
#  'transcend',
#  'combat',
#  'flatter',
#  'untrusting',
#  'sweet',
#  'summarise',
#  'uneasy',
#  'teenage',
#  'restricted',
#  'consider&gt;!35',
#  'ogle',
#  'uncomfortable',
#  'ca',
#  'apologise',
#  'dissappear',
#  'perpetuate',
#  "wan't",
#  'single',
#  'overthink',
#  'eats',
#  'portion',
#  'feeling',
#  'consist',
#  'harder',
#  'lightheaded',
#  'ate',
#  '’re',
#  'ofc',
#  'nervous',
#  'bigger',
#  'inundate',
#  'playing',
#  'coming',
#  'sore',
#  'nightmare',
#  'hitted',
#  'romanticize',
#  'breakdown',
#  'ration',
#  'decent',
#  'downplay',
#  'shit',
#  'bolused',
#  'kicked',
#  'loved',
#  'email',
#  'etc',
#  'excersise',
#  'reset',
#  'pm',
#  'dishonor',
#  'scrutinise',
#  "'s",
#  'enlighten',
#  'nauseous',
#  'exacerbate',
#  'pity',
#  'beyond',
#  'badger',
#  'finishing',
#  'avoiding',
#  'gorge',
#  'proana',
#  'resurface',
#  'eff',
#  'emotional',
#  'to',
#  'conjure',
#  'glad',
#  'illicit',
#  'seep',
#  'heavy',
#  'fatshaming',
#  'taking',
#  'warp',
#  'alleviate',
#  'talks',
#  'up',
#  'couple',
#  'pacing',
#  'fetishise',
#  'adress',
#  'delude',
#  'eddy(my',
#  'overwork',
#  'dislike',
#  'noticeable',
#  'beautiful',
#  'cope',
#  'final',
#  'dose',
#  'undeserving',
#  'inhibit',
#  'normalize',
#  'does',
#  'uproot',
#  'spice',
#  'dwindle',
#  'critique',
#  'burden',
#  'nihilistic',
#  'healty',
#  'terrifies',
#  's',
#  'lot',
#  'careful',
#  'sexualise',
#  'replie',
#  'miniskirt',
#  'dissociate',
#  'm',
#  'happier',
#  'alive',
#  'partake',
#  'shame',
#  'parent',
#  'suceeded',
#  'distance',
#  'besides',
#  'proud',
#  'paralyse',
#  'thanksgiving',
#  'sadder',
#  'came',
#  'felt',
#  'shallow',
#  'nauseus',
#  'removing',
#  'pain',
#  'dull',
#  'appetizing',
#  'scare',
#  'psychoanalyze',
#  'instagram',
#  'vacuum',
#  'skipping',
#  'loss',
#  'belong',
#  'putting',
#  'soooo',
#  'zone',
#  'black',
#  'triggering',
#  'distant',
#  'pester',
#  'fck',
#  'incapable',
#  'excusing',
#  'tracking',
#  'reoccurred',
#  'bitch',
#  'bully',
#  'specialize',
#  'thibner',
#  'intermittent',
#  'has',
#  'gear',
#  'ought',
#  'gross',
#  'disable',
#  'weaponise',
#  'valuable',
#  'download',
#  'recreate',
#  'ugh',
#  'throiughout',
#  'elses',
#  'guilted',
#  'stop-',
#  'food',
#  'resentful',
#  'slimmer',
#  'shine',
#  'impossible',
#  'cookies',
#  'journey',
#  'kno',
#  'excited',
#  'tout',
#  'fluctuate',
#  'abort',
#  'skinnier',
#  'overreact',
#  'hardcore',
#  'ik',
#  'alternative',
#  'large',
#  'fuckable',
#  'i‘m',
#  'veggie',
#  'chugging',
#  'prepped',
#  'sad',
#  'spoon',
#  'glamorize',
#  'boyfriend',
#  'hits',
#  'infuse',
#  'censor',
#  'unprotected',
#  'bought',
#  'stomach',
#  'restart',
#  'predispose',
#  'replacements',
#  'rediscover',
#  'pelvic',
#  'cynical',
#  'blah',
#  'meals',
#  'paranoid',
#  'favourite',
#  'unsure',
#  'overrule',
#  'weak',
#  'butter',
#  'peak',
#  'spank',
#  'reimburse',
#  'motion',
#  'dye',
#  'persist',
#  'meeting',
#  'harrassed',
#  'babysitting',
#  'weird',
#  'temper',
#  'detox',
#  'doordashed',
#  'tube',
#  'underweight',
#  'texted',
#  'angry',
#  'texts',
#  'manageable',
#  'overcook',
#  'protein',
#  'hiccup',
#  'fucked',
#  'mess',
#  'squeezing',
#  'plot',
#  'rebel',
#  'uglier',
#  'dunno',
#  'wolf',
#  'moderate',
#  'ravenous',
#  'loving',
#  'applied',
#  'obsess',
#  'resubmit',
#  'b',
#  'good.!&lt',
#  'section',
#  'making',
#  'fat',
#  'reign',
#  'forced',
#  'guilty',
#  'flit',
#  'home',
#  'painful',
#  'liquidise',
#  'lol',
#  'slim',
#  'conscious',
#  'overdo',
#  'hangouts',
#  'calories/',
#  'silly',
#  'nourish',
#  'thoughts',
#  'adult',
#  'gulfed',
#  'afraid',
#  'mentality',
#  'wanna',
#  '’m',
#  'unfazed',
#  'adhd',
#  'watched',
#  'loathe',
#  'accountable',
#  'jumpstart',
#  'intertwine',
#  'unfreeze',
#  "'d",
#  'either',
#  'subject',
#  'videoing',
#  'wishing',
#  'hypothesise',
#  'out',
#  'gained',
#  'foods',
#  'unalive',
#  'f',
#  'branch',
#  'hotter',
#  'coffee',
#  'not',
#  'due',
#  'molest',
#  'captain',
#  'lucky',
#  'forcing',
#  'asking',
#  'equal',
#  'fund',
#  'fault',
#  'prioritize',
#  'egg',
#  'mechanize',
#  'self',
#  'unwell',
#  'been',
#  "'m",
#  'arfid',
#  'worth',
#  'yay',
#  'mad',
#  'sham',
#  'freak',
#  'traumatize',
#  'healthier',
#  'organise',
#  'late',
#  'lethargic',
#  'cheered',
#  'kind',
#  'advice',
#  'terrorize',
#  'alienate',
#  'k*ll',
#  'goes,”are',
#  'other',
#  'host',
#  'hava',
#  'squander',
#  'expire',
#  'jealous',
#  'dizzy',
#  '😌',
#  'plateau',
#  'antagonise',
#  'talkative',
#  'breakfast',
#  'likely',
#  'substitute',
#  'calorie',
#  'het',
#  'eating',
#  'fived',
#  'fuck',
#  'frequent',
#  'makes',
#  'pressure',
#  'ghost',
#  'undiagnosed',
#  'lax',
#  'word',
#  'sideline',
#  'triple',
#  'gt;!sometimes',
#  'doordash',
#  'research',
#  'unmanageable',
#  'excercise',
#  'disorder',
#  'person',
#  'sugar',
#  'advoid',
#  'cycle',
#  'mc',
#  'sk*nny',
#  'ti',
#  'unlive',
#  'dairy',
#  'exclaim',
#  'therapist',
#  'stump',
#  'lapse',
#  'hoard',
#  'approval',
#  'fot',
#  'cross-',
#  'impact',
#  'hyper',
#  'harrass',
#  'point',
#  'lust',
#  'easy',
#  'lowkey',
#  'irregulating',
#  'jus',
#  'hopeful',
#  'cupcakes',
#  'awkward',
#  'insecure',
#  'unstable',
#  'hate',
#  'dont',
#  'telling',
#  'child',
#  'reflux',
#  'noticed',
#  'cardio',
#  'reposts',
#  'hungry',
#  'disordered',
#  'thirsty',
#  'folks',
#  'less',
#  'overdose',
#  'were',
#  'bait',
#  'quell',
#  'sacrafyse',
#  'petite',
#  '\\-cutting',
#  'exhibit',
#  'pizza',
#  'sweaty',
#  'calories',
#  'motivation',
#  'regurgitate',
#  'shun',
#  'stem',
#  'tweet',
#  'fatshamed',
#  'can',
#  'unexciting',
#  'wo',
#  'vulnerable',
#  'cone',
#  'irk',
#  'stare',
#  'dehydrate',
#  'at',
#  'confident',
#  'kinda',
#  'offset',
#  'othering',
#  'spite',
#  'satiate',
#  'competitive',
#  'v*mited',
#  'different',
#  'wise',
#  'wrt',
#  'infliltrated',
#  'relapse',
#  'closed',
#  'thing',
#  'nutritionist',
#  'flairs',
#  'motherly',
#  'yea',
#  'developed',
#  'isnʻt',
#  'derealize',
#  'gainded',
#  'overdraw',
#  'burp',
#  'treating',
#  'ill',
#  'babysit',
#  'experiment',
#  'desperate',
#  'obese',
#  'stronger',
#  'obligate',
#  'fatter',
#  'sandwich',
#  'cancle',
#  'with',
#  '’s',
#  'rationalize',
#  'thanks',
#  'compound',
#  'constantly',
#  'gaslighting',
#  'follower',
#  'wigging',
#  'bombard',
#  'envious',
#  'bc',
#  'stymie',
#  'starbucks',
#  'reprocess',
#  'disguisting',
#  'growing',
#  'anxiety',
#  'seen',
#  'stupid',
#  'preface',
#  'log',
#  'body',
#  'overshoot',
#  'hypersensitive',
#  'lookit',
#  'slapped',
#  'contextualize',
#  'fester',
#  'favorite',
#  'rephrase',
#  'aspire',
#  'ed',
#  'wants',
#  'true',
#  'bad',
#  'losing',
#  'happiness',
#  'suicidal',
#  'i’m',
#  'cherish',
#  'whatever',
#  'withstand',
#  'joyous',
#  'ivc',
#  'map',
#  'bulk',
#  'morph',
#  'vow',
#  'restructure',
#  'waterboard',
#  'naked',
#  'scorn',
#  'bathroom',
#  'gaslight',
#  'incline',
#  'higher',
#  'embarrassment',
#  'someone',
#  'v*mit',
#  'full',
#  'inpatient',
#  'micromanage',
#  'priority',
#  'ridicule',
#  'reoccurring',
#  'amaze',
#  'might',
#  'bolded',
#  'fucking',
#  'validate',
#  "'re",
#  'expierienced',
#  'reliant',
#  'problems',
#  'diagnosis',
#  'strated',
#  'workout',
#  'every',
#  'fret',
#  'belive',
#  'redirect',
#  'sharing',
#  '•',
#  'ingrain',
#  'meds',
#  'reintroduce',
#  'awful',
#  'bloat',
#  '’d',
#  'refeeding',
#  'beginning',
#  '6’4',
#  'comfortable',
#  'skeleton',
#  'nag',
#  'w',
#  'style',
#  'override',
#  'high',
#  'spawn',
#  'meatballs',
#  'overfeed',
#  'overstep',
#  'doing',
#  'facetime',
#  'esteem',
#  'unattractive',
#  'coincide',
#  'such',
#  'socialize',
#  'delete',
#  'friendless',
#  'day',
#  'itch',
#  'gassy',
#  'laundry',
#  'adulting',
#  'unnecessary',
#  'obsessive',
#  'starving',
#  'italian',
#  'disease',
#  'weight',
#  'constipate',
#  'abt',
#  'glorify',
#  'bulimic',
#  'specified',
#  'pooped',
#  'reffered',
#  'taper',
#  'bastard',
#  'nauseas',
#  'unplanned',
#  'demean',
#  'retell',
#  'reschedule',
#  'heaviest',
#  'unhealthy',
#  'dm',
#  'tougher',
#  'crawed',
#  'replicate',
#  'fizzy',
#  'plug',
#  'allot',
#  'biggest',
#  'remark',
#  'hella',
#  'lasagna',
#  'except',
#  'demonise',
#  'consolidate',
#  'resistant',
#  'objectify',
#  'effect',
#  'diddnt',
#  'giver',
#  'complications',
#  'trek',
#  'author',
#  'overate',
#  'disregard',
#  'triggered',
#  'birth',
#  'form.a',
#  'orange',
#  'tarnish',
#  'manifest',
#  'unhappy',
#  'balloon',
#  'update',
#  'clam',
#  'restricting',
#  'short',
#  'girl',
#  'knowthe',
#  'revere',
#  'knowing',
#  'attractive',
#  'skinnyfat',
#  'replay',
#  'package',
#  'remer',
#  'should',
#  'accepting',
#  'p',
#  'anxious',
#  'dumb',
#  'reawaken',
#  '83lbs',
#  'prolong',
#  'screw',
#  "'ve",
#  'traumatise',
#  'percieve',
#  'liar',
#  'abrupty',
#  'emotionless',
#  'pleeeeaaase',
#  'sick',
#  'decouple',
#  'zero',
#  'fell',
#  'goof',
#  'hope',
#  'hestitated',
#  'dealing',
#  'watching',
#  'model',
#  'pretty',
#  'weekly',
#  'sais',
#  'fantasize',
#  'cuss',
#  'hey',
#  'incentivized',
#  'left',
#  'passed',
#  'duds',
#  'unbearable',
#  'irl',
#  'gained.!&lt',
#  'overthinking',
#  'crazy',
#  'outgrow',
#  'fetishize',
#  'hungrier',
#  'drinking',
#  'strive',
#  'bodybuilding',
#  'bender',
#  'ingest',
#  'overestimate',
#  'eatting',
#  'suit',
#  'eke',
#  'flavour',
#  'anorexia',
#  'pore',
#  'meal',
#  'may',
#  'busy',
#  'was',
#  'terrrifies',
#  'agoraphobic',
#  'gt;!skipping',
#  'redownloaded',
#  'incentivised',
#  'demo',
#  'had',
#  'useless',
#  'selfish',
#  '-when',
#  'infiltrate',
#  'reality',
#  'fkk',
#  'squirrel',
#  'necessarily',
#  "dm'd",
#  'funnel',
#  'swaddle',
#  'condition',
#  'donuts',
#  'accomodate',
#  'chastise',
#  'difficult',
#  'ugly',
#  'regroup',
#  'baby',
#  'unparalleled',
#  'befriend',
#  'fatshame',
#  'spare',
#  'about',
#  'invalid',
#  'insists',
#  'under',
#  'guilt',
#  'repulsive',
#  'big',
#  'nauseate',
#  'controlling',
#  '’ve',
#  'having',
#  'overmedicating',
#  'chore',
#  'suck',
#  'figuring',
#  'piss',
#  'discontinue',
#  'sleepy',
#  'medicate',
#  'hinder',
#  'hospitalize',
#  'deform',
#  'indoctrinate',
#  'thinner',
#  'hates',
#  'curb',
#  'pleasuring',
#  'kills',
#  'hype',
#  'berate',
#  'sum',
#  'v',
#  'ride',
#  'sap',
#  'vocalize',
#  'dissapont',
#  'supplement',
#  'ai',
#  'tunnel',
#  'nows',
#  'reference',
#  'ashamed',
#  'kindof',
#  'freaked',
#  'something',
#  'would',
#  'harming',
#  'did',
#  'bottle',
#  'deficient',
#  'uncomfy',
#  'fcked',
#  'gutted',
#  '•avoiding',
#  'over',
#  'confide',
#  'infuriate',
#  'new',
#  'stunt',
#  'islolates',
#  'wean',
#  'overload',
#  'vaping',
#  'resuscitate',
#  'numb',
#  'always',
#  '’ll',
#  'normaly',
#  'available',
#  'discipline',
#  'bodychecks',
#  'savour',
#  'healthy',
#  'told',
#  'snapchat',
#  'distill',
#  'tho',
#  'hating',
#  'spending',
#  '*',
#  'smaller',
#  'requries',
#  'infantilizing',
#  'what',
#  'reprimand',
#  'restrictive',
#  'fighting',
#  'certify',
#  'hilarious',
#  'similar',
#  're',
#  'ecen',
#  'degrade',
#  'summarize',
#  'revolt',
#  'therapizing',
#  'terrified',
#  'waisting',
#  'demonize',
#  'evoke',
#  'equalize',
#  'curious',
#  'minutes',
#  'purge/',
#  'purge',
#  'defrost',
#  'vomit',
#  'belittle',
#  'sabotage',
#  'empower',
#  'thrive',
#  'impersonate',
#  'craft',
#  'died',
#  'phase',
#  'un',
#  'confusme',
#  'good',
#  'roommates',
#  'overcompensate',
#  'fcking',
#  'sent',
#  'in',
#  'small',
#  'bodycheck',
#  'honour',
#  '️ve',
#  'factor',
#  'skinny',
#  'wit',
#  'kickstarted',
#  'worse',
#  'trying',
#  'reclaim',
#  'railroad',
#  'gon',
#  'bf',
#  'visible',
#  'helpful',
#  'more',
#  'attended',
#  'outweigh',
#  'young',
#  'aware',
#  'overeat',
#  'dirty',
#  'message',
#  'puke',
#  'so',
#  'idealize',
#  'fits',
#  'spat',
#  'denying',
#  'mimick',
#  'hi',
#  'forego',
#  'romanticise',
#  'deteriorate',
#  'vegan',
#  'texting',
#  'up.~~.',
#  'supportive',
#  'compliment',
#  'prettier',
#  'google',
#  'facetimed',
#  'insane',
#  'gang',
#  'mature',
#  'prep',
#  'guy',
#  'knows',
#  'regress',
#  'prepping',
#  'resort',
#  'implode',
#  'be',
#  'bribe',
#  'binge',
#  'off',
#  'triangulate',
#  'overweight',
#  'guzzle',
#  'tank',
#  'enrol',
#  'cos',
#  '/know/',
#  'divest',
#  'telemed',
#  'intake',
#  'helped',
#  'missed',
#  'used',
#  'calling',
#  'discomfort',
#  'lovesmy',
#  'relate',
#  ...}

# %% [markdown]
# <br><br><br><br>
#
# # Examine the persona coverage
#
# For each persona, print how often the persona was used with a verb that was matched or not matched to the lexicon

# %%
persona_found_dict, persona_missed_dict, persona_total_dict = pf.evaluate_persona_coverage(id_persona_total_dict, id_persona_power_dict)

# %%
persona_found_dict
# Out:
# defaultdict(int,
#             {'food': 5298,
#              'therapist': 324,
#              'medical_prof': 1263,
#              'narrator': 14008,
#              'reader': 4053,
#              'ex_SO': 1513,
#              'family': 3527,
#              'SO_female': 403,
#              'SO_any': 1491,
#              'friend': 2015,
#              'SO_male': 780,
#              'ED': 2109,
#              'doctor': 778,
#              'SO_neutral': 308,
#              'nurse': 95})

# %%
agency_found_dict, agency_missed_dict, agency_total_dict = pf.evaluate_persona_coverage(id_persona_total_dict, id_persona_agency_dict)

# %%
agency_found_dict
# Out:
# defaultdict(int,
#             {'food': 652,
#              'therapist': 371,
#              'medical_prof': 1065,
#              'reader': 3458,
#              'narrator': 3906,
#              'ex_SO': 500,
#              'family': 3619,
#              'SO_female': 418,
#              'SO_any': 1692,
#              'friend': 2029,
#              'SO_male': 946,
#              'ED': 574,
#              'doctor': 559,
#              'SO_neutral': 328,
#              'nurse': 52})

# %%
for _persona, _total in persona_total_dict.items():
    print(_persona)
    print('Matched:', persona_found_dict[_persona], '(' + str(round((persona_found_dict[_persona] / _total) * 100, 1)) + '%)')
    print('Not Matched:', persona_missed_dict[_persona], '(' + str(round((persona_missed_dict[_persona] / _total) * 100, 1)) + '%)')
    print()
# Out:
# food
# Matched: 5298 (80.5%)
# Not Matched: 1284 (19.5%)
#
# therapist
# Matched: 324 (59.8%)
# Not Matched: 218 (40.2%)
#
# medical_prof
# Matched: 1263 (66.2%)
# Not Matched: 646 (33.8%)
#
# narrator
# Matched: 14008 (63.0%)
# Not Matched: 8210 (37.0%)
#
# reader
# Matched: 4053 (65.2%)
# Not Matched: 2168 (34.8%)
#
# ex_SO
# Matched: 1513 (77.7%)
# Not Matched: 433 (22.3%)
#
# family
# Matched: 3527 (56.1%)
# Not Matched: 2755 (43.9%)
#
# SO_female
# Matched: 403 (49.7%)
# Not Matched: 408 (50.3%)
#
# SO_any
# Matched: 1491 (52.3%)
# Not Matched: 1362 (47.7%)
#
# friend
# Matched: 2015 (53.8%)
# Not Matched: 1729 (46.2%)
#
# SO_male
# Matched: 780 (52.7%)
# Not Matched: 699 (47.3%)
#
# ED
# Matched: 2109 (84.6%)
# Not Matched: 385 (15.4%)
#
# doctor
# Matched: 778 (73.3%)
# Not Matched: 283 (26.7%)
#
# SO_neutral
# Matched: 308 (55.6%)
# Not Matched: 246 (44.4%)
#
# nurse
# Matched: 95 (74.8%)
# Not Matched: 32 (25.2%)
